# %% [markdown]
# # Prompt Rescue Workshop
#
# ## Diagnose and fix a broken production prompt
#
# You're a technical consultant who just got pulled into a struggling project. Your client, **TechSupport Corp**, has a prompt running in production that processes support tickets — classifying priority, extracting key details, and drafting responses, all in one shot. It works on clean inputs but fails badly on messy real-world tickets: priorities are wrong, entities are hallucinated, JSON breaks, and responses contradict the classification.
#
# The client's renewal meeting is in 48 hours. Your job: rescue this prompt.
#
# ### Learning Objectives
#
# By the end of this workshop, you will be able to:
#
# 1. **Diagnose** root causes of prompt failure by analyzing output patterns against intended behavior
# 2. **Apply** structured prompt engineering techniques (meta-prompting, chaining, decomposition) to fix underperforming prompts
# 3. **Evaluate** prompt iterations using a systematic eval harness rather than vibes-based assessment
# 4. **Implement** prompt chains that decompose complex single-prompt tasks into reliable multi-step workflows
# 5. **Defend** prompt design decisions with evidence from eval results
#
# ### Format
#
# This is a **solo exercise**. Work at your own pace through the cells below.
#
# **Suggested time budget:** ~15 min diagnosis → ~45 min building → ~10 min reflection + sharing

# %%
# Install the Anthropic SDK
# !pip install -q anthropic matplotlib --upgrade

# API Key Configuration
import os
# ANTHROPIC_API_KEY = ""  # <-- Paste your API key here
# os.environ["ANTHROPIC_API_KEY"] = ANTHROPIC_API_KEY

# Verify connection
import anthropic
client = anthropic.Anthropic()
test = client.messages.create(
    model="claude-haiku-4-5",
    max_tokens=50,
    messages=[{"role": "user", "content": "Say 'Connected!' and nothing else."}]
)
print(f"API Connected: {test.content[0].text}")
# Out:
# API Connected: Connected!

# %% [markdown]
# ## The Scenario: TechSupport Corp
#
# ### Customer Brief
#
# > "We're TechSupport Corp, an enterprise SaaS company. We built a prompt to handle incoming support tickets — classify priority, extract key details, and draft a response, all in one shot. It works great on simple, clearly-written tickets. But in production, maybe half the tickets are messy — multiple issues, vague descriptions, non-native English speakers. Those fail badly. JSON comes back broken, priorities are wrong, and the drafted responses sometimes contradict the classification. We need this fixed before our renewal meeting. One constraint: our ticketing pipeline has a 5-second latency budget per ticket, so solutions requiring more than 3 sequential API calls need justification."
#
# ### The Challenge
#
# 1. **Diagnose** the root causes of failure (not just symptoms — *why* does the prompt structure produce these failures?)
# 2. **Fix** the prompt using at least two techniques from your toolkit (see "Your Toolkit" below)
# 3. **Validate** your fix against the eval suite
# 4. **Present** a 3-minute "customer debrief" — diagnosis, fix, results, and prevention advice
#
# ### Success Criteria
#
# | Level | Target |
# |-------|--------|
# | **Baseline (Pass)** | 75%+ eval pass rate, root cause identified, 2+ techniques used with justification, coherent debrief |
# | **Tier 1 — Optimizer** | 90%+ pass rate, documented iteration log, monitoring prompt design |
# | **Tier 2 — Architect** | Self-healing prompt chain (auto-retry on quality check failure) |
#
# ### Constraints
#
# - **Model:** Claude Haiku (hardcoded in the eval harness — no model upgrades as a fix)
# - **Architecture:** You may completely restructure the prompt — including breaking it into multiple steps or a chain — but the end-to-end function must remain the same: same inputs in, same type of outputs out
# - **Process:** Track each prompt iteration. The eval harness logs your progression automatically.

# %%
# ============================================================
# YOUR PROMPT -- Edit this to fix the broken prompt!
# ============================================================

system_prompt = """
You are a support ticket processor. For each ticket, you must:
1. Classify priority (P1-P4) based on business impact
2. Extract: product name, version, error codes, affected users count
3. Draft a helpful response acknowledging the issue and providing next steps
4. Return everything as JSON: {"priority": "", "entities": {"product": "", "version": "", "error_codes": [], "affected_users": ""}, "response": "", "confidence": "high/medium/low"}

Rules:
- P1 = system down, all users affected
- P2 = major feature broken, many users affected
- P3 = minor bug, few users affected
- P4 = feature request or cosmetic issue
- If unsure about priority, use your best judgment
- Response should be professional and empathetic
- Always include all JSON fields even if empty
- Be concise but thorough
"""

print("Broken prompt loaded. Run the eval suite (Cell 7) to see your baseline score.")
print(f"Prompt length: {len(system_prompt)} characters")
# Out:
# Broken prompt loaded. Run the eval suite (Cell 7) to see your baseline score.
# Prompt length: 792 characters

# %%
# ============================================================
# YOUR PROMPT -- Edit this to fix the broken prompt!
# ============================================================

system_prompt_2 = """
You are a support ticket processor. Analyze the ticket below in three stages.

## STAGE 1 — PRIORITY (base on CONTENT only, never tone)

Assign exactly one priority:
- P1: System down OR data loss OR security/privacy breach OR payroll/financial process blocked
- P2: Major feature broken, significant user impact, production regression
- P3: Minor bug, intermittent issue, single user affected, cosmetic defect
- P4: Feature request, suggestion, or missing capability — REGARDLESS of how urgently it is worded

CRITICAL PRIORITY RULES:
- Angry tone, caps lock, or threatening language does NOT raise priority
- Polite tone does NOT lower priority
- A missing feature that has never existed is always P4, even if the customer says "CRITICAL" or "UNACCEPTABLE"
- If multiple issues are present, use the HIGHEST applicable priority
- If information is too vague to determine severity, default to P3

## STAGE 2 — ENTITY EXTRACTION (only extract what is explicitly stated)

Extract these four fields:
- product: name of the product or module mentioned — null if not stated
- version: version number mentioned — null if not stated
- error_codes: list of error codes, HTTP status codes, or quoted error messages — empty list [] if none
- affected_users: numeric count of affected users as a string — null if no specific number given

CRITICAL EXTRACTION RULES:
- NEVER invent or infer a value that is not explicitly in the ticket
- Vague words like "several", "some", "my team", "many" are NOT a number — set affected_users to null
- If the ticket mentions no product name, set product to null — do not guess
- Only include error codes that appear verbatim in the ticket

## STAGE 3 — RESPONSE DRAFT

Write a professional response that:
- Matches the urgency of the priority (P1: immediate action tone; P4: appreciation + expectation-setting)
- Acknowledges ALL issues mentioned in the ticket — never drop an issue
- For P4 feature requests: acknowledge as a feature request, do NOT promise to "fix" it
- For vague tickets (confidence=low): ask clarifying questions rather than making assumptions
- For non-English or broken English: respond in clear English, do not comment on language quality

## OUTPUT FORMAT

Return ONLY valid JSON. No explanation, no markdown fences, no text before or after.

{
  "priority": "P1|P2|P3|P4",
  "entities": {
    "product": "string or null",
    "version": "string or null",
    "error_codes": ["array of strings, empty if none"],
    "affected_users": "numeric string or null"
  },
  "response": "professional response to the customer",
  "confidence": "high|medium|low"
}
"""

print("Improved prompt v1 loaded.")
print(f"Prompt length: {len(system_prompt)} characters")
# Out:
# Improved prompt v1 loaded.
# Prompt length: 2607 characters

# %% [markdown]
# ## Failing Examples — Diagnosis Material
#
# These are 5 real inputs where the broken prompt fails. Study the patterns before you start fixing.
#
# ---
#
# ### Example 1: Multi-issue ticket
#
# **Input:**
# ```
# Subject: URGENT - billing broken AND can't export data
#
# Our billing dashboard has been showing wrong numbers since Tuesday and also the CSV export
# feature throws a 500 error. We have board reporting on Friday and need both fixed. About 200
# users on our team are affected by the export issue, billing is just our finance team (3 people)
# but it's blocking payroll.
# ```
#
# **What went wrong:** Classifies as P2 (should be P1 — payroll is blocked). Merges both issues into one entity extraction. Response only addresses the export issue, ignoring the billing/payroll problem.
#
# ---
#
# ### Example 2: Vague ticket
#
# **Input:**
# ```
# Subject: things arent working right
#
# hey so a bunch of stuff seems off today? like the pages load slow and sometimes i get errors.
# not sure whats happening. its been like this since the morning. thanks
# ```
#
# **What went wrong:** Hallucinates product name "PageLoader" and error code "ERR_SLOW_LOAD" that don't exist anywhere in the input. Classifies as P3 when there's not enough info to classify confidently.
#
# ---
#
# ### Example 3: Non-native English
#
# **Input:**
# ```
# Subject: Probleme mit der Integration
#
# Hello, we have problem with API integration since update to version 3.2. The webhook is not
# fire correctly and data is missing in dashboard. Very urgent for us because is production
# system for 50 customer. Error say "timeout exceeded" sometimes.
# ```
#
# **What went wrong:** JSON output is malformed — the response field contains a quote that breaks the JSON structure. Priority is correct (P2) but entities miss the version number.
#
# ---
#
# ### Example 4: Feature request disguised as bug
#
# **Input:**
# ```
# Subject: BUG: No dark mode support
#
# This is a critical usability bug. Your application doesn't support dark mode which causes eye
# strain for our entire team working night shifts (15 people). This should have been implemented
# long ago. We need this resolved immediately or we'll consider switching providers.
# ```
#
# **What went wrong:** Classifies as P2 due to urgent language, when this is clearly P4 (feature request). Response promises to "fix the bug" which sets wrong customer expectations.
#
# ---
#
# ### Example 5: Clean ticket (regression check)
#
# **Input:**
# ```
# Subject: Error 503 on login page
#
# Since 2pm EST today, all users (approximately 500) in our organization are unable to log into
# the platform. We receive a 503 Service Unavailable error. This is our primary CRM tool and
# sales team is completely blocked. Error code: SVC-503-AUTH. Running version 4.1.2.
# ```
#
# **What went wrong:** Actually handles this correctly most of the time (clean input). Include to verify fixes don't regress on easy cases.

# %%
#@title Eval Harness (click to load -- do not edit this cell)

# ============================================================
# EVAL HARNESS -- All evaluation logic is embedded here.
# Run this cell once to load the harness functions.
# ============================================================

import json
import re
import base64
import time
from datetime import datetime
import anthropic
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import display, HTML
matplotlib.rcParams['figure.facecolor'] = 'white'

# ---------------------------------------------------------------------------
# Embedded eval cases (base64-encoded to discourage casual peeking)
# ---------------------------------------------------------------------------

_EVAL_CASES_B64 = "..."

# ---------------------------------------------------------------------------
# Global state
# ---------------------------------------------------------------------------

_iteration_log = []
_baseline_score = None
_baseline_total = None

MODEL = "claude-haiku-4-5"
MAX_TOKENS = 4096

# ---------------------------------------------------------------------------
# Case loader
# ---------------------------------------------------------------------------

def _load_cases(encoded):
    return json.loads(base64.b64decode(encoded).decode("utf-8"))

# ---------------------------------------------------------------------------
# Scoring module (ported from scoring.py)
# ---------------------------------------------------------------------------

REQUIRED_FIELDS = {"priority", "entities", "response", "confidence"}
REQUIRED_ENTITY_FIELDS = {"product", "version", "error_codes", "affected_users"}


def parse_output(raw_output):
    """Extract JSON from model output, handling nested objects."""
    try:
        parsed = json.loads(raw_output.strip())
        return parsed, None
    except json.JSONDecodeError:
        pass
    start_indices = [i for i, c in enumerate(raw_output) if c == '{']
    for start in start_indices:
        brace_count = 0
        for end in range(start, len(raw_output)):
            if raw_output[end] == '{':
                brace_count += 1
            elif raw_output[end] == '}':
                brace_count -= 1
            if brace_count == 0:
                candidate = raw_output[start:end + 1]
                try:
                    parsed = json.loads(candidate)
                    return parsed, None
                except json.JSONDecodeError:
                    break
    return None, "Output is not valid JSON"


def check_valid_json(parsed, error):
    if parsed is None:
        return False, error or "Output is not valid JSON"
    missing_top = REQUIRED_FIELDS - set(parsed.keys())
    if missing_top:
        return False, f"Missing required fields: {', '.join(sorted(missing_top))}"
    entities = parsed.get("entities")
    if not isinstance(entities, dict):
        return False, "Field 'entities' must be a JSON object"
    missing_entity = REQUIRED_ENTITY_FIELDS - set(entities.keys())
    if missing_entity:
        return False, f"Missing entity fields: {', '.join(sorted(missing_entity))}"
    return True, "Valid JSON with all required fields"


def check_priority(parsed, gold_priority):
    if parsed is None:
        return False, "Cannot check priority -- invalid JSON"
    output_priority = str(parsed.get("priority", "")).strip().upper()
    expected = gold_priority.strip().upper()
    if output_priority == expected:
        return True, f"Priority correct: {expected}"
    return False, f"Priority={output_priority}, expected={expected}"


def _normalize_value(val):
    return re.sub(r'[\s\-_\.]+', ' ', str(val).lower().strip())


_NULL_EQUIVALENT_PATTERN = re.compile(
    r'^('
    r'null|none|n/?a|unknown|unspecified|not\s+specified'
    r'|not\s+provided|not\s+mentioned|not\s+available'
    r'|unknown\s*[-\u2014\u2013]\s*not\s+\w+'
    r'|\w+\s*\(unspecified[^)]*\)'
    r')$',
    re.IGNORECASE,
)


def _is_null_equivalent(val_str):
    """Return True if a value is semantically null (model saying 'not present')."""
    return bool(_NULL_EQUIVALENT_PATTERN.match(val_str.strip()))


def _strip_annotations(val):
    """Strip parenthetical suffixes and leading approximation markers."""
    val = re.sub(r'\s*\(.*?\)\s*$', '', val)
    val = re.sub(r'^[~\u2248]\s*', '', val)
    return val.strip()


def _value_in_input(value, input_text):
    """Check if an entity value is derivable from the input text."""
    if value is None or value == "" or value == []:
        return True
    input_lower = input_text.lower()
    input_normalized = _normalize_value(input_text)
    if isinstance(value, list):
        return all(_value_in_input(v, input_text) for v in value)
    val_str = str(value).strip()
    if not val_str or _is_null_equivalent(val_str):
        return True
    val_lower = val_str.lower()
    val_normalized = _normalize_value(val_str)
    if val_lower in input_lower:
        return True
    if val_normalized in input_normalized:
        return True
    if re.match(r'^\d+$', val_str):
        if re.search(r'\b' + re.escape(val_str) + r'\b', input_text):
            return True
    if re.match(r'^\d+\.\d+(\.\d+)?$', val_str):
        if val_str in input_text:
            return True
    # Fallback: strip annotations and retry
    stripped = _strip_annotations(val_str)
    if stripped and stripped != val_str:
        if _value_in_input(stripped, input_text):
            return True
    # Fallback: numeric value with approximation in input
    num_match = re.match(r'^[~\u2248]?\s*(\d+(?:\.\d+)?)\s*$', val_str)
    if num_match:
        number = num_match.group(1)
        approx_pattern = (
            r'(?:approximately|about|around|roughly|~|\u2248)\s*'
            + re.escape(number)
        )
        if re.search(approx_pattern, input_text, re.IGNORECASE):
            return True
        if re.search(r'\b' + re.escape(number) + r'\b', input_text):
            return True
    # Fallback: comma-separated multi-values
    if ',' in val_str:
        parts = [p.strip() for p in val_str.split(',') if p.strip()]
        if len(parts) > 1 and all(
            _value_in_input(part, input_text) for part in parts
        ):
            return True
    return False


def check_entities(parsed, input_text, gold_entities):
    if parsed is None:
        return False, "Cannot check entities -- invalid JSON"
    entities = parsed.get("entities", {})
    if not isinstance(entities, dict):
        return False, "Entities field is not a JSON object"
    hallucinated = []
    for field in REQUIRED_ENTITY_FIELDS:
        value = entities.get(field)
        if value is None or value == "" or value == []:
            continue
        if not _value_in_input(value, input_text):
            hallucinated.append(f"{field}={json.dumps(value)}")
    if hallucinated:
        return False, f"Possible hallucinated entities: {'; '.join(hallucinated)}"
    return True, "All entities derivable from input"


def score_case(parsed, parse_error, input_text, gold_priority, gold_entities,
               response_coherent=None, audited=False):
    json_ok, json_reason = check_valid_json(parsed, parse_error)
    priority_ok, priority_reason = (False, "Skipped -- invalid JSON") if not json_ok else check_priority(parsed, gold_priority)
    entities_ok, entities_reason = (False, "Skipped -- invalid JSON") if not json_ok else check_entities(parsed, input_text, gold_entities)
    if not audited:
        response_ok = True
        response_reason = "Auto-pass (non-audited case)"
    elif not json_ok:
        response_ok = False
        response_reason = "Skipped -- invalid JSON"
    elif response_coherent is None:
        response_ok = True
        response_reason = "Pending judge evaluation"
    else:
        response_ok = response_coherent
        response_reason = "Judge: PASS" if response_coherent else "Judge: FAIL"
    all_pass = json_ok and priority_ok and entities_ok and response_ok
    return {
        "pass": all_pass,
        "criteria": {
            "json_valid": {"pass": json_ok, "reason": json_reason},
            "priority_correct": {"pass": priority_ok, "reason": priority_reason},
            "entities_accurate": {"pass": entities_ok, "reason": entities_reason},
            "response_coherent": {"pass": response_ok, "reason": response_reason},
        },
    }

# ---------------------------------------------------------------------------
# Judge prompt module (ported from judge_prompts.py)
# ---------------------------------------------------------------------------

JUDGE_SYSTEM_PROMPT = """You are an eval judge for a support ticket processing system. Your job is to assess whether a drafted response appropriately addresses the support ticket given the priority classification.

Rules:
- The response must not contradict the priority classification
- The response must address the actual content of the ticket
- For feature requests classified as P4: the response must NOT promise to "fix" it or treat it as a bug
- For vague tickets: the response should ask for more information
- For multi-issue tickets: the response should acknowledge all issues mentioned
- Tone should be professional regardless of the ticket's tone

Reply with exactly one line: PASS or FAIL followed by a one-sentence reason.
Example: PASS - Response appropriately acknowledges the feature request and sets expectations.
Example: FAIL - Response promises to fix a feature request as if it were a bug."""


def judge_response(client, input_text, priority, response_text):
    user_message = f"""Evaluate this support ticket response:

SUPPORT TICKET:
{input_text}

ASSIGNED PRIORITY: {priority}

DRAFTED RESPONSE:
{response_text}

Does the response appropriately address the ticket without contradicting the classification? Reply PASS or FAIL with a one-sentence reason."""
    try:
        result = _call_api_with_retry(
            client, model=MODEL, max_tokens=150, system=JUDGE_SYSTEM_PROMPT,
            messages=[{"role": "user", "content": user_message}],
        )
        judge_output = result.content[0].text.strip()
        if judge_output.upper().startswith("PASS"):
            return True, judge_output
        elif judge_output.upper().startswith("FAIL"):
            return False, judge_output
        else:
            return True, f"Ambiguous judge output (defaulting to PASS): {judge_output}"
    except Exception as e:
        return True, f"Judge call failed (defaulting to PASS): {e}"

# ---------------------------------------------------------------------------
# Core eval runner
# ---------------------------------------------------------------------------

def _call_api_with_retry(client, **kwargs):
    """Wrap API calls with exponential backoff for rate limits and overloaded errors."""
    delays = [1, 2, 4]
    last_err = None
    for attempt in range(len(delays) + 1):
        try:
            return client.messages.create(**kwargs)
        except anthropic.RateLimitError as e:
            last_err = e
        except anthropic.APIStatusError as e:
            if e.status_code == 529:
                last_err = e
            else:
                raise
        if attempt < len(delays):
            print(f" (retry {attempt+1} in {delays[attempt]}s)", end="", flush=True)
            time.sleep(delays[attempt])
    raise last_err


def run_single_prompt(client, system_prompt, user_input):
    result = _call_api_with_retry(
        client, model=MODEL, max_tokens=MAX_TOKENS, system=system_prompt,
        messages=[{"role": "user", "content": user_input}],
    )
    return result.content[0].text


def run_chain(client, prompts, user_input):
    output = ""
    step_outputs = []
    for i, system_prompt in enumerate(prompts):
        if i == 0:
            user_message = user_input
        else:
            parts = [f"ORIGINAL TICKET:\n{user_input}"]
            for j, prev_output in enumerate(step_outputs):
                parts.append(f"STEP {j+1} OUTPUT:\n{prev_output}")
            user_message = "\n\n".join(parts)
        try:
            output = run_single_prompt(client, system_prompt, user_message)
        except Exception as e:
            output = json.dumps({"error": f"Chain step {i+1} failed: {e}"})
        step_outputs.append(output)
    return output


def run_eval(client, prompts, cases_data, verbose=False):
    cases = cases_data["cases"]
    categories = cases_data["categories"]
    total = len(cases)
    results = []
    print(f"Running {total} eval cases...")
    for i, case in enumerate(cases):
        case_id = case["id"]
        print(f"  Case {case_id:>2}/{total}...", end="", flush=True)
        try:
            if len(prompts) == 1:
                raw_output = run_single_prompt(client, prompts[0], case["input"])
            else:
                raw_output = run_chain(client, prompts, case["input"])
        except Exception as e:
            raw_output = f"API ERROR: {e}"
        parsed, parse_error = parse_output(raw_output)
        response_coherent = None
        if case.get("audited_response") and parsed:
            priority = parsed.get("priority", "")
            response_text = parsed.get("response", "")
            if response_text:
                judge_pass, judge_reason = judge_response(client, case["input"], priority, response_text)
                response_coherent = judge_pass
        result = score_case(
            parsed=parsed, parse_error=parse_error, input_text=case["input"],
            gold_priority=case["gold_priority"], gold_entities=case["gold_entities"],
            response_coherent=response_coherent, audited=case.get("audited_response", False),
        )
        result["case_id"] = case_id
        result["category"] = case["category"]
        result["raw_output"] = raw_output
        results.append(result)
        status = "PASS" if result["pass"] else "FAIL"
        if result["pass"]:
            print(f" {status}")
        else:
            failed_criteria = [
                name for name, crit in result["criteria"].items()
                if not crit["pass"]
            ]
            reasons = [
                f'{name}: {result["criteria"][name]["reason"]}'
                for name in failed_criteria
            ]
            print(f" {status} [{"; ".join(reasons)}]")
    category_results = {}
    for cat_key, cat_info in categories.items():
        cat_case_ids = cat_info["case_ids"]
        cat_results = [r for r in results if r["case_id"] in cat_case_ids]
        passed = sum(1 for r in cat_results if r["pass"])
        category_results[cat_key] = {
            "label": cat_info["label"],
            "passed": passed,
            "total": len(cat_results),
        }
    total_passed = sum(1 for r in results if r["pass"])
    return {
        "results": results, "categories": category_results,
        "total_passed": total_passed, "total_cases": total,
    }

# ---------------------------------------------------------------------------
# Visualization
# ---------------------------------------------------------------------------

def _score_color(pct):
    if pct >= 80: return "#22c55e"
    if pct >= 60: return "#eab308"
    return "#ef4444"


def _display_results(eval_result, label="Current"):
    global _baseline_score, _baseline_total
    total_passed = eval_result["total_passed"]
    total_cases = eval_result["total_cases"]
    pct = round(100 * total_passed / total_cases) if total_cases else 0
    color = _score_color(pct)

    baseline_html = ""
    if _baseline_score is not None:
        bl_pct = round(100 * _baseline_score / _baseline_total)
        diff = total_passed - _baseline_score
        diff_str = f"+{diff}" if diff >= 0 else str(diff)
        diff_color = "#22c55e" if diff > 0 else ("#ef4444" if diff < 0 else "#6b7280")
        baseline_html = f'<div style="font-size:16px;color:#6b7280;margin-top:4px;">Baseline: {_baseline_score}/{_baseline_total} ({bl_pct}%) &rarr; Current: {total_passed}/{total_cases} ({pct}%) <span style="color:{diff_color};font-weight:bold;">[{diff_str}]</span></div>'

    html = f'''
    <div style="background:#f8fafc;border:2px solid {color};border-radius:12px;padding:24px;margin:16px 0;font-family:system-ui,-apple-system,sans-serif;">
      <div style="text-align:center;">
        <div style="font-size:14px;color:#6b7280;text-transform:uppercase;letter-spacing:1px;">{label}</div>
        <div style="font-size:64px;font-weight:bold;color:{color};">{total_passed}/{total_cases}</div>
        <div style="font-size:24px;color:{color};">({pct}%)</div>
        {baseline_html}
      </div>
    </div>
    '''
    display(HTML(html))

    cats = eval_result["categories"]
    labels = [cats[k]["label"] for k in cats]
    passed = [cats[k]["passed"] for k in cats]
    totals = [cats[k]["total"] for k in cats]
    failed = [t - p for t, p in zip(totals, passed)]

    fig, ax = plt.subplots(figsize=(10, 3.5))
    y_pos = range(len(labels))
    ax.barh(y_pos, passed, color='#22c55e', label='Passed', height=0.6)
    ax.barh(y_pos, failed, left=passed, color='#fee2e2', label='Failed', height=0.6)
    ax.set_yticks(y_pos)
    ax.set_yticklabels(labels, fontsize=12)
    ax.set_xlabel('Cases', fontsize=12)
    ax.set_title('Score by Category', fontsize=14, fontweight='bold')
    ax.legend(loc='lower right')
    for i, (p, t) in enumerate(zip(passed, totals)):
        ax.text(t + 0.1, i, f'{p}/{t}', va='center', fontsize=11, fontweight='bold')
    ax.set_xlim(0, max(totals) + 1.5)
    ax.invert_yaxis()
    plt.tight_layout()
    plt.show()


def _log_run(label, eval_result):
    _iteration_log.append({
        "timestamp": datetime.now().strftime("%H:%M:%S"),
        "label": label,
        "passed": eval_result["total_passed"],
        "total": eval_result["total_cases"],
        "pct": round(100 * eval_result["total_passed"] / eval_result["total_cases"]),
        "categories": {k: v.copy() for k, v in eval_result["categories"].items()},
    })

# ---------------------------------------------------------------------------
# Public API -- these are the functions teams use
# ---------------------------------------------------------------------------

def run_eval_suite(prompt_or_prompts, label="Current"):
    """Run the full eval suite and display visual results.

    Args:
        prompt_or_prompts: Either a single system prompt string,
                          or a list of prompt strings for chain mode.
        label: A label for this run (shown in results and iteration log).
    """
    global _baseline_score, _baseline_total

    client = anthropic.Anthropic()
    cases_data = _load_cases(_EVAL_CASES_B64)

    if isinstance(prompt_or_prompts, str):
        prompts = [prompt_or_prompts]
        mode = "single prompt"
    else:
        prompts = list(prompt_or_prompts)
        mode = f"{len(prompts)}-step chain"

    print(f"Mode: {mode}")
    print(f"Model: {MODEL}")
    print()

    start_time = time.time()
    eval_result = run_eval(client, prompts, cases_data)
    elapsed = time.time() - start_time

    print(f"\nCompleted in {elapsed:.1f}s")

    if _baseline_score is None:
        _baseline_score = eval_result["total_passed"]
        _baseline_total = eval_result["total_cases"]
        print(f"Baseline set: {_baseline_score}/{_baseline_total}")

    _log_run(label, eval_result)
    _display_results(eval_result, label=label)
    return eval_result


def compare_prompts(prompt_a, prompt_b, label_a="Variant A", label_b="Variant B"):
    """Run two prompt variants and display side-by-side comparison."""
    client = anthropic.Anthropic()
    cases_data = _load_cases(_EVAL_CASES_B64)

    prompts_a = [prompt_a] if isinstance(prompt_a, str) else list(prompt_a)
    prompts_b = [prompt_b] if isinstance(prompt_b, str) else list(prompt_b)

    print(f"Running {label_a}...")
    result_a = run_eval(client, prompts_a, cases_data)
    print(f"\nRunning {label_b}...")
    result_b = run_eval(client, prompts_b, cases_data)

    _log_run(label_a, result_a)
    _log_run(label_b, result_b)

    pct_a = round(100 * result_a["total_passed"] / result_a["total_cases"])
    pct_b = round(100 * result_b["total_passed"] / result_b["total_cases"])

    html = f'''
    <div style="display:flex;gap:16px;margin:16px 0;font-family:system-ui,-apple-system,sans-serif;">
      <div style="flex:1;background:#f8fafc;border:2px solid {_score_color(pct_a)};border-radius:12px;padding:20px;text-align:center;">
        <div style="font-size:13px;color:#6b7280;text-transform:uppercase;">{label_a}</div>
        <div style="font-size:48px;font-weight:bold;color:{_score_color(pct_a)};">{result_a["total_passed"]}/{result_a["total_cases"]}</div>
        <div style="font-size:20px;color:{_score_color(pct_a)};">({pct_a}%)</div>
      </div>
      <div style="flex:1;background:#f8fafc;border:2px solid {_score_color(pct_b)};border-radius:12px;padding:20px;text-align:center;">
        <div style="font-size:13px;color:#6b7280;text-transform:uppercase;">{label_b}</div>
        <div style="font-size:48px;font-weight:bold;color:{_score_color(pct_b)};">{result_b["total_passed"]}/{result_b["total_cases"]}</div>
        <div style="font-size:20px;color:{_score_color(pct_b)};">({pct_b}%)</div>
      </div>
    </div>
    '''
    display(HTML(html))

    cats_a = result_a["categories"]
    cats_b = result_b["categories"]
    cat_keys = list(cats_a.keys())
    labels = [cats_a[k]["label"] for k in cat_keys]
    scores_a = [cats_a[k]["passed"] for k in cat_keys]
    scores_b = [cats_b[k]["passed"] for k in cat_keys]
    totals = [cats_a[k]["total"] for k in cat_keys]

    fig, ax = plt.subplots(figsize=(10, 4))
    y = range(len(labels))
    bar_height = 0.35
    ax.barh([i - bar_height/2 for i in y], scores_a, bar_height, label=label_a, color='#3b82f6')
    ax.barh([i + bar_height/2 for i in y], scores_b, bar_height, label=label_b, color='#f97316')
    ax.set_yticks(list(y))
    ax.set_yticklabels(labels, fontsize=12)
    ax.set_xlabel('Cases Passed', fontsize=12)
    ax.set_title('Category Comparison', fontsize=14, fontweight='bold')
    ax.legend(loc='lower right')
    for i, (sa, sb, t) in enumerate(zip(scores_a, scores_b, totals)):
        ax.text(max(sa, sb) + 0.15, i, f'/{t}', va='center', fontsize=10, color='#6b7280')
    ax.set_xlim(0, max(totals) + 1.5)
    ax.invert_yaxis()
    plt.tight_layout()
    plt.show()

    rows = ""
    for k in cat_keys:
        sa = cats_a[k]["passed"]
        sb = cats_b[k]["passed"]
        t = cats_a[k]["total"]
        diff = sb - sa
        winner = label_b if diff > 0 else (label_a if diff < 0 else "Tie")
        diff_color = "#22c55e" if diff > 0 else ("#ef4444" if diff < 0 else "#6b7280")
        diff_str = f"+{diff}" if diff > 0 else str(diff)
        rows += f'<tr><td>{cats_a[k]["label"]}</td><td>{sa}/{t}</td><td>{sb}/{t}</td><td style="color:{diff_color};font-weight:bold;">{diff_str}</td><td>{winner}</td></tr>'

    table_html = f'''
    <table style="border-collapse:collapse;width:100%;margin:16px 0;font-family:system-ui,-apple-system,sans-serif;">
    <thead><tr style="background:#f1f5f9;"><th style="padding:8px;text-align:left;">Category</th><th>{label_a}</th><th>{label_b}</th><th>Delta</th><th>Winner</th></tr></thead>
    <tbody>{rows}</tbody>
    </table>
    '''
    display(HTML(table_html))
    return result_a, result_b


def show_iteration_log():
    """Display the iteration history as a table and line chart."""
    if not _iteration_log:
        print("No iterations logged yet. Run run_eval_suite() first.")
        return

    rows = ""
    for i, entry in enumerate(_iteration_log):
        color = _score_color(entry["pct"])
        rows += f'<tr><td>{i+1}</td><td>{entry["timestamp"]}</td><td>{entry["label"]}</td><td style="color:{color};font-weight:bold;">{entry["passed"]}/{entry["total"]} ({entry["pct"]}%)</td></tr>'

    table_html = f'''
    <h3 style="font-family:system-ui,-apple-system,sans-serif;">Iteration Log</h3>
    <table style="border-collapse:collapse;width:100%;margin:8px 0;font-family:system-ui,-apple-system,sans-serif;">
    <thead><tr style="background:#f1f5f9;"><th style="padding:8px;text-align:left;">#</th><th>Time</th><th>Label</th><th>Score</th></tr></thead>
    <tbody>{rows}</tbody>
    </table>
    '''
    display(HTML(table_html))

    if len(_iteration_log) > 1:
        fig, ax = plt.subplots(figsize=(10, 4))
        x = range(1, len(_iteration_log) + 1)
        pcts = [e["pct"] for e in _iteration_log]
        ax.plot(x, pcts, 'o-', color='#3b82f6', linewidth=2, markersize=8)
        ax.axhline(y=75, color='#22c55e', linestyle='--', alpha=0.7, label='Pass threshold (75%)')
        ax.axhline(y=90, color='#eab308', linestyle='--', alpha=0.7, label='Optimizer tier (90%)')
        for i, (xi, pct) in enumerate(zip(x, pcts)):
            ax.annotate(f'{pct}%', (xi, pct), textcoords="offset points",
                        xytext=(0, 12), ha='center', fontsize=10, fontweight='bold')
        ax.set_xlabel('Iteration', fontsize=12)
        ax.set_ylabel('Pass Rate (%)', fontsize=12)
        ax.set_title('Score Progression', fontsize=14, fontweight='bold')
        ax.set_ylim(0, 105)
        ax.set_xticks(list(x))
        ax.set_xticklabels([e["label"][:20] for e in _iteration_log], rotation=30, ha='right', fontsize=9)
        ax.legend(loc='lower right')
        plt.tight_layout()
        plt.show()


print("Eval harness loaded.")
print()
print("Available functions:")
print("  run_eval_suite(prompt_or_prompts, label='...')  -- Run full eval, display visual results")
print("  compare_prompts(prompt_a, prompt_b, ...)        -- A/B comparison of two variants")
print("  show_iteration_log()                            -- Show all runs + score progression chart")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Eval harness loaded.
#
# Available functions:
#   run_eval_suite(prompt_or_prompts, label='...')  -- Run full eval, display visual results
#   compare_prompts(prompt_a, prompt_b, ...)        -- A/B comparison of two variants
#   show_iteration_log()                            -- Show all runs + score progression chart

# %%
# ============================================================
# RUN YOUR FIRST EVAL -- Establish your baseline score
# ============================================================

results = run_eval_suite(system_prompt, label="Baseline (Broken Prompt)")
results
# Out:
# Mode: single prompt
# Model: claude-haiku-4-5
#
# Running 21 eval cases...
#   Case  1/21... FAIL [entities_accurate: Possible hallucinated entities: product="CRM Platform"]
#   Case  2/21... PASS
#   Case  3/21... FAIL [priority_correct: Priority=P4, expected=P3]
#   Case  4/21... FAIL [entities_accurate: Possible hallucinated entities: product="Analytics/Reporting Tool"]
#   Case  5/21... FAIL [entities_accurate: Possible hallucinated entities: affected_users="200+ (export issue); 3 (billing accuracy issue)"]
#   Case  6/21... PASS
#   Case  7/21... FAIL [priority_correct: Priority=P2, expected=P3; entities_accurate: Possible hallucinated entities: affected_users="Multiple users (unspecified)"]
#   Case  8/21... FAIL [entities_accurate: Possible hallucinated entities: affected_users="small team"]
#   Case  9/21... FAIL [priority_correct: Priority=P1, expected=P2; entities_accurate: Possible hallucinated entities: product="API Integration/Webhook System"; affected_users="50 customers (production systems)"]
#   Case 10/21... FAIL [entities_accurate: Possible hallucinated entities: product="Report Generation System"; affected_users="3 out of 6 team members"]
#   Case 11/21... FAIL [priority_correct: Priority=P1, expected=P4]
#   Case 12/21... PASS
#   Case 13/21... FAIL [priority_correct: Priority=P1, expected=P2; entities_accurate: Possible hallucinated entities: product="Cloud-hosted platform"]
#   Case 14/21... PASS
#   Case 15/21... FAIL [entities_accurate: Possible hallucinated entities: error_codes=["FEATURE_LOCKED_advanced_cohort_analysis", "FEATURE_LOCKED_custom_funnel_builder", "ACCOUNT_PLAN_MISMATCH"]]
#   Case 16/21... FAIL [entities_accurate: Possible hallucinated entities: product="Data Sync Service"; error_codes=["DUPLICATE_RECORDS_ON_SYNC"]]
#   Case 17/21... PASS
#   Case 18/21... PASS
#   Case 19/21... FAIL [entities_accurate: Possible hallucinated entities: affected_users="All users"]
#   Case 20/21... PASS
#   Case 21/21... FAIL [priority_correct: Priority=P2, expected=P3; entities_accurate: Possible hallucinated entities: error_codes=["timeout"]; affected_users="Multiple users across at least 2 departments (exact count unknown)"]
#
# Completed in 82.0s
# Baseline set: 7/21
#     <div style="background:#f8fafc;border:2px solid #ef4444;border-radius:12px;padding:24px;margin:16px 0;font-family:system-ui,-apple-system,sans-serif;">
#       <div style="text-align:center;">
#         <div style="font-size:14px;color:#6b7280;text-transform:uppercase;letter-spacing:1px;">Baseline (Broken Prompt)</div>
#         <div style="font-size:64px;font-weight:bold;color:#ef4444;">7/21</div>
#         <div style="font-size:24px;color:#ef4444;">(33%)</div>
#         <div style="font-size:16px;color:#6b7280;margin-top:4px;">Baseline: 7/21 (33%) &rarr; Current: 7/21 (33%) <span style="color:#6b7280;font-weight:bold;">[+0]</span></div>
#       </div>
#     </div>
# {'results': [{'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: product="CRM Platform"'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 1,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": "CRM Platform",\n    "version": "4.1.2",\n    "error_codes": ["SVC-503-AUTH"],\n    "affected_users": "500"\n  },\n  "response": "Thank you for reporting this critical issue. We understand that a 503 Service Unavailable error on the login page is completely blocking access to your CRM for all 500 users—we recognize the urgent business impact this has on your sales team.\\n\\nWe are treating this as a highest-priority incident (P1) and have immediately escalated to our engineering team. Our incident response team is actively investigating the authentication service failure associated with error code SVC-503-AUTH on version 4.1.2.\\n\\nNext steps:\\n1. Our engineers are currently diagnosing the root cause and working on a fix\\n2. We will provide a status update within 30 minutes\\n3. Once resolved, we will communicate the fix and expected service restoration time\\n\\nIn the meantime, please confirm:\\n- Are you able to access the platform from any alternative network/location?\\n- Have you experienced any recent infrastructure changes on your end?\\n\\nWe apologize for this disruption and will keep you updated throughout the resolution process. Please reply immediately with any additional details that could help expedite our investigation.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 2,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "Inventory Management Module",\n    "version": "2.8.0",\n    "error_codes": [],\n    "affected_users": "45"\n  },\n  "response": "Thank you for reporting this issue. We sincerely apologize for the search malfunction affecting your warehouse team\'s daily operations. This is clearly a significant concern that requires immediate attention.\\n\\nBased on your report, we\'ve identified that the issue began with yesterday\'s 2.8.0 update. We\'re treating this as a high-priority case given the impact on 45 users.\\n\\nNext steps:\\n1. Our engineering team is investigating the search algorithm changes introduced in v2.8.0\\n2. In the meantime, please try clearing your browser cache or restarting the application\\n3. If available, consider temporarily reverting to v2.7.x until we deploy a fix\\n4. We\'ll prioritize a patch and aim to have an update within 24 hours\\n\\nPlease confirm if clearing the cache helps, and let us know if you need any further assistance.",\n  "confidence": "high"\n}\n```'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': False, 'reason': 'Priority=P4, expected=P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 3,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P4",\n  "entities": {\n    "product": "Admin Settings Page",\n    "version": "5.0.1",\n    "error_codes": [],\n    "affected_users": "2 (admins during training)"\n  },\n  "response": "Thank you for reporting this issue. We appreciate you catching the truncated tooltip text on the Data Retention Policy field in the admin settings page. While this is a cosmetic issue that doesn\'t impact functionality, we understand it can be confusing during onboarding.\\n\\nNext steps:\\n1. We\'ll log this as a UI refinement for our next release\\n2. In the meantime, admins can find the complete Data Retention Policy documentation in our help center\\n3. If you need the full tooltip text immediately for training purposes, please let us know and we can provide it directly\\n\\nThis will be prioritized in our backlog for version 5.1 or later. Thanks for helping us improve the user experience!",\n  "confidence": "high"\n}\n```'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P4'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: product="Analytics/Reporting Tool"'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 4,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P4",\n  "entities": {\n    "product": "Analytics/Reporting Tool",\n    "version": "",\n    "error_codes": [],\n    "affected_users": "8"\n  },\n  "response": "Thank you for submitting this feature request! We appreciate the detailed suggestion for bulk PDF export functionality with a \'Select All\' checkbox and \'Export Selected to PDF\' button. This would indeed streamline workflows for teams that manage multiple reports regularly.\\n\\nWe\'ve logged this as a feature request and will include it in our product roadmap review. The analytics team use case you\'ve described is valuable input for prioritization.\\n\\nIn the meantime, if you need a workaround for exporting multiple reports more efficiently, our support team may be able to suggest some alternatives. Feel free to reach out if you have any other questions.\\n\\nThank you for helping us improve our product!",\n  "confidence": "high"\n}\n```'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: affected_users="200+ (export issue); 3 (billing accuracy issue)"'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 5,
#    'category': 'multi_issue',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": "Billing Dashboard",\n    "version": "",\n    "error_codes": ["500"],\n    "affected_users": "200+ (export issue); 3 (billing accuracy issue)"\n  },\n  "response": "Thank you for reporting this critical issue. We understand the urgency given your Friday board deadline and payroll impact.\\n\\nWe\'re immediately escalating this as a P1 incident affecting both your billing accuracy and data export functionality. Our engineering team is investigating:\\n\\n1. **Billing Dashboard** - incorrect calculations since Tuesday\\n2. **CSV Export** - 500 error preventing data extraction\\n\\n**Immediate next steps:**\\n- Our team will provide an initial status update within 1 hour\\n- We\'re prioritizing a fix for both issues given your Friday deadline\\n- In the interim, please reach out to our support team if you need workarounds for payroll processing\\n\\nA dedicated engineer will contact you within 30 minutes to gather additional details (affected date range, sample billing discrepancies, export parameters). Please have your finance team and a technical contact available.\\n\\nWe recognize the business-critical nature of this and will keep you updated every 2 hours until resolved.",\n  "confidence": "high"\n}\n```\n\n**Why P1:** System down/severely degraded with wide user impact (200+ blocked from export), plus financial operations blocked (payroll). Time-sensitive business deadline increases severity.'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 6,
#    'category': 'multi_issue',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "Real-time Analytics Dashboard",\n    "version": "3.5",\n    "error_codes": [],\n    "affected_users": "12"\n  },\n  "response": "Thank you for reporting these issues. We understand the critical nature of your dashboard outage—stale data for 3 days significantly impacts your ops team\'s shift planning.\\n\\nFor the stale data issue (Priority 2):\\n- We\'re treating this as a high-priority bug and will investigate immediately\\n- Please confirm: are you seeing any error messages in your browser console or application logs?\\n- In the meantime, can your team access historical data through our API as a workaround?\\n- We\'ll follow up within 2 hours with initial findings\\n\\nRegarding dark mode (Priority 4):\\n- Thank you for the feature suggestion—we\'ve logged this in our product backlog\\n- We\'ll share this feedback with our UX team for consideration in future releases\\n\\nPlease reply with any error codes or logs you\'ve captured so we can expedite the resolution.",\n  "confidence": "high"\n}\n```\n\n**Note:** I\'ve classified these as two separate issues. The dashboard data bug is **P2** (major feature broken, significant user impact), while the dark mode request is **P4** (feature request). You may want to create separate tickets for tracking purposes.'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': False, 'reason': 'Priority=P2, expected=P3'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: affected_users="Multiple users (unspecified)"'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 7,
#    'category': 'vague',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "Unknown",\n    "version": "Unknown",\n    "error_codes": [],\n    "affected_users": "Multiple users (unspecified)"\n  },\n  "response": "Thank you for reporting this issue. We understand you\'re experiencing slow page loads and intermittent errors since this morning, which we take seriously.\\n\\nTo help us investigate quickly, could you please provide:\\n1. Which specific product or application you\'re using\\n2. Your browser type and version\\n3. Any error messages or codes you\'re seeing (screenshots helpful)\\n4. Which pages or features are affected\\n5. Your approximate location/timezone\\n\\nWe\'re looking into potential performance issues on our end. In the meantime, try clearing your browser cache and restarting your session. We\'ll prioritize this and follow up within 2 hours.\\n\\nThank you for your patience!",\n  "confidence": "medium"\n}\n```\n\n**Note:** Confidence is "medium" because the ticket lacks critical details (product name, specific error codes, version info). The P2 classification reflects multiple users affected with functionality impact, but could be escalated to P1 if this represents widespread system failure.'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: affected_users="small team"'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 8,
#    'category': 'vague',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": "unspecified",\n    "version": "unspecified",\n    "error_codes": [],\n    "affected_users": "small team"\n  },\n  "response": "Thank you for bringing this to our attention, and we sincerely appreciate your 3 years of loyalty. We understand your frustration, and we take concerns about platform quality very seriously.\\n\\nTo help us investigate and address the specific issues affecting your team, could you please provide:\\n\\n1. **Specific examples**: What particular features or behaviors aren\'t working as expected?\\n2. **Product/version**: Which product are you using and what version?\\n3. **Error messages**: Any error codes or messages you\'re encountering?\\n4. **Timeline**: When did you first notice these issues?\\n\\nOnce we have these details, we can prioritize your case and work toward a resolution. Your feedback is valuable, and we\'d like the opportunity to restore your confidence in our platform.\\n\\nPlease reply with these details or reach out to our support team directly.",\n  "confidence": "medium"\n}\n```\n\n**Note**: This ticket lacks specific technical details needed for thorough diagnosis. It\'s classified as P3 (quality concern affecting a team) rather than P1-P2 because no system outage or broken feature is explicitly described. A follow-up with concrete examples is essential to escalate appropriately.'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': False, 'reason': 'Priority=P1, expected=P2'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: product="API Integration/Webhook System"; affected_users="50 customers (production systems)"'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 9,
#    'category': 'non_native',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": "API Integration/Webhook System",\n    "version": "3.2",\n    "error_codes": [\n      "timeout exceeded"\n    ],\n    "affected_users": "50 customers (production systems)"\n  },\n  "response": "Thank you for reporting this critical issue. We understand the urgency given the production impact on your 50 customers.\\n\\nWe\'ve identified that version 3.2 has introduced a webhook timeout issue causing data loss in the dashboard. This requires immediate attention.\\n\\nNext steps:\\n1. **Immediate**: Consider rolling back to version 3.1 as a temporary mitigation if possible\\n2. **Urgent**: Our engineering team is investigating the timeout mechanism in webhook handlers\\n3. **Action needed from you**: Please provide:\\n   - Specific webhook endpoint URLs affected\\n   - Timestamp of when issues began\\n   - Sample of missing data/failed webhook payloads\\n   - Your API timeout configuration settings\\n\\n4. **Follow-up**: We will escalate this to our development team and provide a hotfix within 4 hours\\n\\nPlease reply with the information above or contact our emergency support line immediately for priority handling.",\n  "confidence": "high"\n}\n```'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: product="Report Generation System"; affected_users="3 out of 6 team members"'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 10,
#    'category': 'non_native',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": "Report Generation System",\n    "version": "2.1",\n    "error_codes": [],\n    "affected_users": "3 out of 6 team members"\n  },\n  "response": "Thank you for reaching out, and please don\'t worry about your English—we understand completely!\\n\\nWe\'ve received your report about the report button not working consistently in version 2.1. We appreciate you providing those details about your team.\\n\\n**Next Steps:**\\n1. Could you please tell us which browser and browser version your team is using? (Chrome, Firefox, Safari, Edge, etc.)\\n2. When the button doesn\'t work, do you see any error messages or does it simply not respond?\\n3. Does clearing your browser cache help temporarily?\\n4. Are the 3 affected team members using the same browser/computer setup?\\n\\nThis information will help us identify if this is a browser compatibility issue or something else. In the meantime, if you discover a workaround that helps, please let us know.\\n\\nWe\'re here to help!",\n  "confidence": "medium"\n}\n```\n\n**Summary:** Intermittent button functionality affecting ~50% of a small team. Likely browser-related based on user\'s observation. Needs more technical details (browser type, error messages) to properly diagnose. Priority is P3 (minor bug, limited user impact) rather than P2 because the feature works sometimes and affects a small group.'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': False, 'reason': 'Priority=P1, expected=P4'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 11,
#    'category': 'feature_request',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": "Platform",\n    "version": "",\n    "error_codes": [],\n    "affected_users": "2000"\n  },\n  "response": "Thank you for bringing this critical compliance requirement to our attention. We understand that SAML SSO integration is essential for your organization\'s security posture and that this impacts all 2000 of your users.\\n\\nWe take this matter with the highest urgency. Here are our immediate next steps:\\n\\n1. **Escalation**: I\'m escalating this to our Product and Engineering leadership immediately, flagging the one-week timeline and compliance requirement.\\n\\n2. **Executive Engagement**: Our Account Management team will contact your organization today to understand the specific SAML requirements and any workarounds that might temporarily address compliance needs.\\n\\n3. **Technical Assessment**: Our engineering team will evaluate the feasibility and timeline for SAML SSO implementation.\\n\\n4. **Follow-up**: You\'ll receive a status update within 24 hours with either a concrete implementation plan or interim solutions.\\n\\nIn the meantime, please provide us with:\\n- Your specific SAML 2.0 requirements\\n- Compliance framework requirements (SOC 2, ISO 27001, etc.)\\n- Any technical documentation from your CISO\\n\\nWe\'re committed to finding a solution that meets your security requirements.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P4'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 12,
#    'category': 'feature_request',
#    'raw_output': '```json\n{\n  "priority": "P4",\n  "entities": {\n    "product": "Task Management Module",\n    "version": "",\n    "error_codes": [],\n    "affected_users": "5"\n  },\n  "response": "Thank you for the thoughtful feature suggestion! We appreciate your feedback on adding a calendar view to the task management module. A visual calendar representation for deadlines is definitely valuable for project planning and can improve team visibility.\\n\\nWe\'ve logged this as a feature request for our product team to evaluate. While we can\'t commit to a timeline, requests like yours help us prioritize improvements that deliver the most value to our users.\\n\\nIn the meantime, if you\'d like to discuss workarounds or other ways to visualize your project timelines, feel free to reach out.\\n\\nThanks again for using our product!",\n  "confidence": "high"\n}\n```'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': False, 'reason': 'Priority=P1, expected=P2'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: product="Cloud-hosted platform"'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 13,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": "Cloud-hosted platform",\n    "version": "6.0",\n    "error_codes": [\n      "UPLOAD-TIMEOUT-413",\n      "429"\n    ],\n    "affected_users": "85 (entire engineering team)"\n  },\n  "response": "Dear Sarah,\\n\\nThank you for the detailed report and for documenting these issues comprehensively. We sincerely apologize for the performance degradation you\'re experiencing following your migration to version 6.0. We recognize this falls well short of your SLA expectations and the service quality you should receive.\\n\\nWe are treating this as a critical P1 issue and have immediately escalated your case to our infrastructure and cloud operations teams. The combination of increased page load times, notification delays, upload timeouts (UPLOAD-TIMEOUT-413), aggressive rate limiting (429 errors), and query performance degradation suggests potential infrastructure configuration or resource allocation issues that warrant urgent investigation.\\n\\nNext steps:\\n1. Our infrastructure lead will contact you within 2 hours to schedule a dedicated call this week\\n2. We will perform an immediate audit of your cloud instance configuration and resource allocation\\n3. We will review migration logs and compare pre/post migration performance baselines\\n4. We will temporarily adjust rate limiting parameters to restore your automation workflows\\n\\nIn the interim, please provide:\\n- Your cloud instance ID and region\\n- Specific timeline of when degradation began\\n- A sample of the API requests experiencing 429 errors\\n\\nYour Enterprise plan SLA is our commitment, and we\'re fully committed to restoring performance. You will hear from us shortly.\\n\\nBest regards,\\nSupport Team",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 14,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "API",\n    "version": "2.4.1",\n    "error_codes": ["SYNC_FAILED", "NullPointerException"],\n    "affected_users": "~30 users"\n  },\n  "response": "Thank you for reporting this issue. We\'ve identified a critical bug in the /api/v2/users/sync endpoint (v2.4.1) where special characters in user names trigger a NullPointerException in UserSyncService.java:142. This is preventing synchronization for approximately 30 users in your HR integration.\\n\\n**Immediate Next Steps:**\\n1. We\'ve logged this as P2 with trace_id abc-123-def-456 for investigation\\n2. As a workaround, you can temporarily normalize user names by removing/replacing special characters (e.g., O\'Brien → OBrien) until we release a patch\\n3. Our engineering team will prioritize a fix for this character encoding issue\\n\\n**What we\'ll do:**\\n- Investigate the null pointer exception in UserSyncService.java:142\\n- Test with various special characters (accents, apostrophes, etc.)\\n- Release a hotfix in v2.4.2 within 24-48 hours\\n- Notify you with patch details and testing recommendations\\n\\nPlease confirm the workaround is feasible for your workflow, and let us know if you need any additional details about the error trace.",\n  "confidence": "high"\n}\n```'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: error_codes=["FEATURE_LOCKED_advanced_cohort_analysis", "FEATURE_LOCKED_custom_funnel_builder", "ACCOUNT_PLAN_MISMATCH"]'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 15,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "Analytics Pro",\n    "version": "4.2",\n    "error_codes": [\n      "FEATURE_LOCKED_advanced_cohort_analysis",\n      "FEATURE_LOCKED_custom_funnel_builder",\n      "ACCOUNT_PLAN_MISMATCH"\n    ],\n    "affected_users": "8"\n  },\n  "response": "Thank you for reporting this issue, and we sincerely apologize for the frustration. We understand how critical it is that your team has access to the Pro features you\'ve purchased.\\n\\nWe\'ve identified the root cause: your account shows a provisioning mismatch where the billing tier is set to Pro, but the feature entitlements are provisioned as Basic. This explains why:\\n- Advanced cohort analysis isn\'t accessible\\n- Custom funnel builder requires an upgrade\\n- Your /account endpoint returns \\"analytics_basic\\"\\n\\nNext steps:\\n1. We\'ll immediately re-provision your account with correct Pro entitlements (this typically takes 5-10 minutes)\\n2. Your team should see all Pro features available after re-login\\n3. We\'ll validate the fix with you within 2 hours\\n4. We\'ll investigate why this provisioning error occurred to prevent recurrence\\n\\nPlease reply with your account ID or the email associated with your Analytics Pro subscription, and we\'ll prioritize this correction immediately. If you experience any issues after re-provisioning, we\'re here to help.",\n  "confidence": "high"\n}\n```'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: product="Data Sync Service"; error_codes=["DUPLICATE_RECORDS_ON_SYNC"]'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 16,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "Data Sync Service",\n    "version": "3.1",\n    "error_codes": [\n      "DUPLICATE_RECORDS_ON_SYNC"\n    ],\n    "affected_users": "25"\n  },\n  "response": "Thank you for the follow-up on Case #4821. We appreciate you reporting this regression—while we\'re glad the hourly syncs are now running, duplicate record creation is a serious data integrity issue that requires immediate attention.\\n\\nBased on your observation, it appears the deduplication logic may not have been included in last week\'s patch. I\'m escalating this to our engineering team right away to:\\n\\n1. Verify the deduplication implementation in v3.1\\n2. Identify why duplicates are being created on each sync cycle\\n3. Provide either a hotfix or a targeted patch\\n\\nIn the meantime, please avoid triggering manual syncs if possible to prevent further data duplication. We\'ll prioritize this regression and aim to have a resolution within 24 hours.\\n\\nI\'ll update you as soon as we have more information. Please reply if you need any additional troubleshooting steps in the interim.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 17,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": "Unknown - not specified",\n    "version": "Unknown - not specified",\n    "error_codes": [],\n    "affected_users": "150"\n  },\n  "response": "We sincerely apologize for the critical issue you\'ve experienced. Data loss during end-of-quarter processing is a serious matter that we take with the utmost urgency.\\n\\nImmediate next steps:\\n1. Our senior technical team is being engaged now to investigate the crash and assess data recovery options\\n2. Please reply with: product name, version number, and the exact time the crash occurred\\n3. Do NOT restart or perform any operations on the affected system until we advise\\n4. We will assign a dedicated incident manager to your case within 15 minutes\\n\\nWe understand the critical business impact affecting 150 users and the time sensitivity. We\'re prioritizing this as our highest severity incident.\\n\\nPlease confirm receipt and provide the requested details so we can proceed immediately.",\n  "confidence": "high"\n}\n```\n\n**Internal notes:** \n- P1 classification justified by: system crash + data loss + 150 users affected + critical business timing (EOQ processing)\n- Product/version details missing - must obtain immediately for technical investigation\n- Customer is clearly distressed but communication is legitimate critical incident\n- Assign dedicated incident commander\n- Initiate data recovery procedures in parallel with customer contact'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 18,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": "",\n    "version": "",\n    "error_codes": [],\n    "affected_users": ""\n  },\n  "response": "Thank you for reaching out. We understand you\'re experiencing an issue. To help us resolve this quickly, could you please provide the following details:\\n\\n1. **Product name** - Which product are you using?\\n2. **What\'s broken** - What specific feature or functionality isn\'t working?\\n3. **Error message** - Are you seeing any error codes or messages?\\n4. **Steps to reproduce** - How can we replicate the issue?\\n5. **Your environment** - What version are you on, and what browser/OS are you using?\\n6. **When it started** - When did you first notice this problem?\\n\\nOnce you provide these details, we\'ll be able to prioritize your case and get you a solution as quickly as possible.",\n  "confidence": "low"\n}\n```'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: affected_users="All users"'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 19,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": "UserVault",\n    "version": "9.1.0",\n    "error_codes": [],\n    "affected_users": "All users"\n  },\n  "response": "Thank you for reporting this critical security vulnerability. We take data protection extremely seriously and appreciate you bringing this to our attention promptly.\\n\\nWe have immediately escalated this to our security team and engineering leadership as a P1 incident. Based on your description of exposing PII across user accounts, this requires urgent investigation and remediation.\\n\\n**Immediate next steps:**\\n1. Our security team will investigate the account settings tab-switching behavior in v9.1.0\\n2. We will audit recent access logs to determine the scope of potential exposure\\n3. We will prioritize a patch for immediate deployment\\n\\n**What we need from you:**\\n- Can you provide the approximate time(s) when you reproduced this issue?\\n- Did you capture any screenshots or logs?\\n- Have you shared this finding with anyone else?\\n\\nPlease do not share details of this vulnerability publicly until we\'ve issued a patch. We will provide updates within 4 hours and keep you informed of our progress.\\n\\nThis will be our top priority. Thank you for responsible disclosure.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 20,
#    'category': 'non_native',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "Ñoño Analytics",\n    "version": "5.4.2",\n    "error_codes": ["VIZ-RENDER-408"],\n    "affected_users": "15"\n  },\n  "response": "Dear José,\\n\\nThank you for reporting this issue and providing detailed information. We understand how critical the analytics dashboard is for your daily reporting workflows, and we sincerely apologize for the disruption caused by the 5.4.2 update.\\n\\nWe have identified your case as a high-priority issue affecting your visualization rendering. The error code VIZ-RENDER-408 suggests a charting library initialization problem introduced in the recent release.\\n\\nImmediate next steps:\\n1. We are escalating this to our engineering team for urgent investigation\\n2. As a temporary workaround, please try accessing the dashboard in incognito/private mode to rule out any persistent cache issues\\n3. If available, consider exporting data tables to alternative tools until we resolve this\\n\\nWe will prioritize a hotfix and contact you within 4 hours with either a resolution or detailed timeline. Please reply with:\\n- Your company name and account ID\\n- Screenshot of the error message if possible\\n- Your browser and operating system details\\n\\nWe appreciate your patience and will keep you updated throughout the resolution process.\\n\\nBest regards,\\nSupport Team",\n  "confidence": "high"\n}\n```'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': False, 'reason': 'Priority=P2, expected=P3'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: error_codes=["timeout"]; affected_users="Multiple users across at least 2 departments (exact count unknown)"'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 21,
#    'category': 'vague',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "Report Builder",\n    "version": "",\n    "error_codes": [\n      "timeout"\n    ],\n    "affected_users": "Multiple users across at least 2 departments (exact count unknown)"\n  },\n  "response": "Thank you for reporting this issue. We understand how frustrating performance inconsistencies and timeouts in the report builder can be, especially when they impact your team\'s productivity.\\n\\nWe\'ve noted that multiple users across your team and potentially other departments are experiencing:\\n- Extended report generation times\\n- Timeout errors resulting in failed report generation\\n- Intermittent reliability issues that sometimes resolve on retry\\n\\nNext steps:\\n1. Could you provide us with 2-3 specific examples of affected reports (names, approximate timestamps)? This will help us investigate the root cause.\\n2. When timeouts occur, please note the approximate report size/complexity and any error messages displayed.\\n3. In the meantime, our team will review recent changes to the report builder and server performance logs.\\n\\nWe\'ll prioritize this investigation and follow up with you within 24 hours with initial findings.\\n\\nPlease reply with the report details mentioned above, or contact us directly if you need immediate assistance.",\n  "confidence": "high"\n}\n```'}],
#  'categories': {'clean': {'label': 'Clean inputs', 'passed': 1, 'total': 4},
#   'multi_issue': {'label': 'Multi-issue', 'passed': 1, 'total': 2},
#   'vague': {'label': 'Vague/unclear', 'passed': 0, 'total': 3},
#   'non_native': {'label': 'Non-native English', 'passed': 1, 'total': 3},
#   'feature_request': {'label': 'Feature requests', 'passed': 1, 'total': 2},
#   'complex': {'label': 'Complex/long/edge', 'passed': 3, 'total': 7}},
#  'total_passed': 7,
#  'total_cases': 21}

# %%
results_2 = run_eval_suite(system_prompt_2, label="Enhanced Prompt_v2")
results_2
# Out:
# Mode: single prompt
# Model: claude-haiku-4-5
#
# Running 21 eval cases...
#   Case  1/21... FAIL [entities_accurate: Possible hallucinated entities: product="CRM platform"]
#   Case  2/21... PASS
#   Case  3/21... PASS
#   Case  4/21... PASS
#   Case  5/21... PASS
#   Case  6/21... PASS
#   Case  7/21... PASS
#   Case  8/21... PASS
#   Case  9/21... PASS
#   Case 10/21... PASS
#   Case 11/21... PASS
#   Case 12/21... PASS
#   Case 13/21... PASS
#   Case 14/21... PASS
#   Case 15/21... PASS
#   Case 16/21... PASS
#   Case 17/21... PASS
#   Case 18/21... PASS
#   Case 19/21... PASS
#   Case 20/21... PASS
#   Case 21/21... FAIL [priority_correct: Priority=P2, expected=P3]
#
# Completed in 77.4s
#     <div style="background:#f8fafc;border:2px solid #22c55e;border-radius:12px;padding:24px;margin:16px 0;font-family:system-ui,-apple-system,sans-serif;">
#       <div style="text-align:center;">
#         <div style="font-size:14px;color:#6b7280;text-transform:uppercase;letter-spacing:1px;">Enhanced Prompt_v2</div>
#         <div style="font-size:64px;font-weight:bold;color:#22c55e;">19/21</div>
#         <div style="font-size:24px;color:#22c55e;">(90%)</div>
#         <div style="font-size:16px;color:#6b7280;margin-top:4px;">Baseline: 7/21 (33%) &rarr; Current: 19/21 (90%) <span style="color:#22c55e;font-weight:bold;">[+12]</span></div>
#       </div>
#     </div>
# {'results': [{'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': False,
#      'reason': 'Possible hallucinated entities: product="CRM platform"'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 1,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": "CRM platform",\n    "version": "4.1.2",\n    "error_codes": ["503", "SVC-503-AUTH"],\n    "affected_users": "500"\n  },\n  "response": "Thank you for reporting this critical issue. We understand that all 500 users in your organization are unable to access the platform due to a 503 Service Unavailable error (SVC-503-AUTH) on the login page since 2pm EST today. This is our highest priority.\\n\\nOur engineering team is immediately investigating the authentication service outage on version 4.1.2. We will:\\n\\n1. Assess the root cause of the service unavailability\\n2. Work to restore login functionality as quickly as possible\\n3. Provide you with updates every 30 minutes until resolution\\n\\nWe recognize the critical impact to your sales team and CRM operations. A senior engineer is being assigned to this case now. Please confirm if you are still experiencing the 503 error, and let us know if you have any additional details about when the issue started or any recent changes to your environment.\\n\\nWe appreciate your patience and will prioritize this restoration.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 2,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "inventory management module",\n    "version": "2.8.0",\n    "error_codes": [],\n    "affected_users": "45"\n  },\n  "response": "Thank you for reporting this issue. We understand the search function returning incorrect results is significantly impacting your warehouse team\'s daily operations, especially with 45 users affected.\\n\\nWe\'ve noted that this behavior began immediately after the update to version 2.8.0, and we\'re treating this as a priority regression. Our team will investigate the search functionality in that release.\\n\\nTo help us diagnose this more quickly, please provide:\\n1. A specific example of a SKU you searched for and what unrelated items were returned\\n2. Whether this occurs for all searches or specific product categories\\n3. Any filters or advanced search options you were using when the incorrect results appeared\\n\\nWe\'ll begin our investigation immediately and will follow up with you within 2 hours with initial findings.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 3,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": "admin settings page",\n    "version": "5.0.1",\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reporting the truncated tooltip on the Data Retention Policy field in the admin settings page. We\'ve documented this cosmetic issue affecting version 5.0.1. Since this is a display defect with limited impact, we\'ll prioritize it for a future release. In the meantime, admins can refer to our documentation for the complete Data Retention Policy details. We\'ll follow up once we have more information about when a fix will be available.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P4'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 4,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P4",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": "8"\n  },\n  "response": "Thank you for sharing this feature request. We understand that bulk export to PDF would streamline your analytics team\'s workflow by eliminating the need to export reports individually. Your suggestion for a \\"Select All\\" checkbox and \\"Export Selected to PDF\\" button is clear and actionable.\\n\\nWe\'ve logged this as a feature request for our product team to review. While we cannot commit to a timeline, requests that improve efficiency for multiple users are valuable input for our roadmap prioritization.\\n\\nIn the meantime, if there are any workarounds or alternative approaches that might help reduce the manual effort, please let us know and we\'ll be happy to explore them with you.\\n\\nThank you for being a valued customer.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 5,
#    'category': 'multi_issue',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": ["500"],\n    "affected_users": "200"\n  },\n  "response": "Thank you for reporting this. We recognize the urgency—both issues require immediate attention.\\n\\nWe are treating this as a critical incident:\\n\\n1. **Billing Dashboard Accuracy** — You\'ve reported incorrect numbers since Tuesday affecting your finance team\'s payroll process. We are prioritizing this for immediate investigation and correction.\\n\\n2. **CSV Export Returning HTTP 500** — This is blocking 200 users. We are investigating the root cause of this error immediately.\\n\\nGiven your Friday board reporting deadline, we are escalating both issues to our senior engineering team right now. You can expect an initial status update within 2 hours and a detailed action plan shortly after.\\n\\nTo help us resolve faster, could you provide:\\n- The specific product/module name (e.g., \\"Finance Pro v2.1\\")?\\n- One example of incorrect billing data (what was shown vs. what should have been)?\\n- The exact timestamp of when the billing numbers first appeared wrong?\\n\\nWe will prioritize getting both systems stable before your Friday deadline.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 6,
#    'category': 'multi_issue',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "real-time analytics dashboard",\n    "version": "3.5",\n    "error_codes": [],\n    "affected_users": "12"\n  },\n  "response": "Thank you for reporting both of these items.\\n\\nFor Issue 1 (Stale Data): We understand that stale analytics data since Monday is impacting your ops team\'s ability to plan shifts effectively. This is a significant production issue that we\'re treating as high priority. We\'re investigating why the dashboard data hasn\'t updated in 3 days on version 3.5. Can you confirm:\\n- Are all metrics showing stale data, or specific ones?\\n- Have there been any recent changes to your data source or network configuration?\\n- What is the timestamp shown on the stale data?\\n\\nWe\'ll work to restore real-time updates immediately.\\n\\nFor Issue 2 (Dark Mode): We appreciate the feature request for dark mode. This is a capability enhancement that we can log for future consideration. Please note this isn\'t a fix for an existing defect but rather a new feature idea. We\'ll track the interest from your team and consider it in our product roadmap.\\n\\nPlease reply with answers to the questions above so we can accelerate the investigation into the stale data issue.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 7,
#    'category': 'vague',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reaching out. We\'re sorry to hear you\'re experiencing slowness and errors this morning. To help us investigate and resolve this quickly, we need a few more details:\\n\\n1. Which product or module are you using when you notice the slowness and errors?\\n2. Can you share the specific error messages or codes you\'re seeing?\\n3. Which browser and device are you using?\\n4. Are you the only one affected, or are others on your team experiencing the same issue?\\n\\nOnce we have this information, we\'ll be able to diagnose the problem and get you back up and running.",\n  "confidence": "low"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 8,
#    'category': 'vague',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reaching out, and I appreciate your 3 years of loyalty. I understand your frustration with the platform experience lately. To help us address your concerns effectively, I\'d like to gather some specific details:\\n\\n1. Which product or module are you experiencing issues with?\\n2. Can you describe specific problems you\'ve encountered (e.g., performance degradation, broken features, error messages)?\\n3. When did you first notice these issues?\\n4. Are there particular error messages or behaviors you\'ve observed?\\n\\nOnce I understand the specific issues affecting your team, I\'ll be able to prioritize them appropriately and work toward a resolution. We value your business and want to ensure you have the best experience possible.",\n  "confidence": "low"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 9,
#    'category': 'non_native',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "API integration",\n    "version": "3.2",\n    "error_codes": ["timeout exceeded"],\n    "affected_users": "50"\n  },\n  "response": "Thank you for reporting this issue. We understand this is affecting your production system and your 50 customers, and we are treating this with appropriate urgency.\\n\\nWe have received your report regarding the API integration problems following your update to version 3.2. You\'ve mentioned two key issues:\\n\\n1. Webhooks not firing correctly\\n2. Missing data in the dashboard\\n3. \\"Timeout exceeded\\" errors occurring intermittently\\n\\nTo help us investigate and resolve this quickly, we need some additional details:\\n\\n- Can you provide specific examples of which webhooks are failing to trigger?\\n- For the missing data in the dashboard, what is the time frame when you first noticed this occurring after the update?\\n- Are the \\"timeout exceeded\\" errors appearing in logs, and if so, can you share the full error message and timestamp?\\n- Are all 50 customers affected equally, or is this isolated to specific accounts or API endpoints?\\n\\nIn the meantime, we recommend:\\n- Reviewing the v3.2 release notes for any breaking changes to the webhook or API behavior\\n- Checking your API rate limits and network connectivity\\n\\nPlease reply with these details at your earliest convenience so we can escalate this appropriately to our engineering team.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 10,
#    'category': 'non_native',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": null,\n    "version": "2.1",\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reporting this issue. I understand that you and your team are experiencing intermittent problems with a report button not working consistently in version 2.1.\\n\\nTo help us investigate and resolve this more effectively, I need a few clarifying details:\\n\\n1. Which product or module are you using when you encounter this problem? (Please provide the exact product name)\\n2. When the button fails to work, do you see any error message displayed, or does nothing happen?\\n3. You mentioned it might be related to the browser — which browser(s) and version(s) are your team members using when they experience the issue?\\n4. Is there a specific action or step that happens right before the button stops responding?\\n\\nOnce you provide these details, we\'ll be able to diagnose the problem more quickly. Thank you for your patience, and please don\'t apologize for your English — your report is clear and helpful.",\n  "confidence": "medium"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P4'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 11,
#    'category': 'feature_request',
#    'raw_output': '```json\n{\n  "priority": "P4",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": "2000"\n  },\n  "response": "Thank you for reaching out. We understand that SAML SSO integration is an important security requirement for your organization. We\'ve noted your request for Single Sign-On capability as a feature request and have logged it with our product team for consideration.\\n\\nTo better understand your needs and explore potential interim solutions, we\'d like to gather some additional information:\\n\\n1. Which specific product or module requires SSO integration?\\n2. Are there any alternative authentication methods currently available in our platform that might help bridge this gap while SSO support is being evaluated?\\n3. What is your deployment model (cloud, on-premise, hybrid)?\\n\\nWhile we cannot commit to a specific timeline for new features, we encourage you to work with your account manager to discuss your compliance requirements and any possible workarounds. We take security and compliance seriously and want to ensure we fully understand your organization\'s needs.\\n\\nPlease reply with the additional details above, and we\'ll escalate this appropriately.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P4'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 12,
#    'category': 'feature_request',
#    'raw_output': '```json\n{\n  "priority": "P4",\n  "entities": {\n    "product": "task management module",\n    "version": null,\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for the feedback! We appreciate you sharing this suggestion. A calendar view for tasks is a great feature request, and we understand how that could help your project managers visualize deadlines more effectively. We\'ll add this to our product feedback list for the team to consider in future roadmap planning. If you have any other suggestions or run into any issues with the current functionality, please don\'t hesitate to reach out.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 13,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "cloud-hosted version",\n    "version": "6.0",\n    "error_codes": [\n      "UPLOAD-TIMEOUT-413",\n      "429"\n    ],\n    "affected_users": "85"\n  },\n  "response": "Hello Sarah,\\n\\nThank you for the detailed report and for documenting these issues comprehensively. We understand the severity of the performance degradation you\'re experiencing across multiple systems following your migration to version 6.0, and we take this seriously.\\n\\nWe\'ve received and logged the following issues:\\n1. Elevated page load times (8-10 seconds vs. prior 1.2 seconds across all modules)\\n2. Real-time notification delay (30-45 seconds vs. near-instant)\\n3. File upload timeouts on files >5MB (error UPLOAD-TIMEOUT-413)\\n4. API rate limiting triggering at 10 requests/minute (429 errors)\\n5. Reporting module database query performance degradation (3-5x slower)\\n\\nGiven that this is affecting 85 users on your Enterprise plan and involves multiple subsystems post-migration, we\'re escalating this to our infrastructure team immediately. We acknowledge your SLA requirements for sub-2-second response times and 99.9% uptime.\\n\\nOur team will reach out within 24 hours to schedule a call this week. In the interim, please reply if you have any additional diagnostic information (error logs, traffic patterns, or timing data) that could accelerate our investigation.\\n\\nWe appreciate your partnership and will work to resolve this promptly.\\n\\nBest regards,\\nSupport Team",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 14,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "API",\n    "version": "2.4.1",\n    "error_codes": ["HTTP 500", "SYNC_FAILED", "NullPointerException"],\n    "affected_users": "30"\n  },\n  "response": "Thank you for reporting this issue with detailed error information. We\'ve identified that the /api/v2/users/sync endpoint is returning HTTP 500 errors when processing users with special characters in their names (such as O\'Brien and García). This is blocking your HR integration for approximately 30 users.\\n\\nWe\'re treating this as a production regression and have escalated it to our backend engineering team for immediate investigation. The NullPointerException in UserSyncService.java:142 indicates a null handling issue that needs to be addressed.\\n\\nIn the meantime, as a potential workaround, you could test whether encoding special characters differently affects the sync behavior, though we\'ll work to resolve the root cause.\\n\\nWe\'ll provide an update within 4 hours with either a fix or a detailed status. Please keep the trace_id (abc-123-def-456) handy for our investigation.\\n\\nDo you have a sample payload we can use to reproduce this locally?",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 15,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "Analytics Pro",\n    "version": "4.2",\n    "error_codes": ["upgrade required"],\n    "affected_users": "8"\n  },\n  "response": "Thank you for reporting this issue. We understand this is blocking your data team\'s access to Pro features they\'ve paid for.\\n\\nWe\'ve identified three related issues in your ticket:\\n1. Advanced cohort analysis is unavailable\\n2. Custom funnel builder displays \\"upgrade required\\" despite Pro status\\n3. The /account endpoint returns \\"analytics_basic\\" instead of the correct Pro plan\\n\\nThis aligns with a provisioning issue on our end. We\'re escalating this to our provisioning and account team immediately to:\\n- Verify your Pro subscription status in our billing system\\n- Re-provision your account with correct Pro entitlements\\n- Confirm the API returns the correct plan designation\\n- Validate that all Pro features are accessible\\n\\nWe\'ll prioritize this and follow up with you within 2 hours with a status update. In the meantime, if you have your account ID or order confirmation handy, please reply with those details to expedite the investigation.\\n\\nWe apologize for this disruption to your team\'s workflow.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 16,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": null,\n    "version": "3.1",\n    "error_codes": [],\n    "affected_users": "25"\n  },\n  "response": "Thank you for the follow-up on Case #4821. We understand that while the hourly syncs have resumed, duplicate records are now being created during each sync cycle for your 25 affected users. This is a significant regression that requires immediate attention.\\n\\nWe will investigate whether the deduplication logic was properly included in last week\'s patch and identify what caused the duplicate record creation. A member of our engineering team will review the deployment and contact you within 4 hours with findings and a path to resolution.\\n\\nIn the meantime, please let us know if you have any workarounds in place or if this issue is blocking critical operations. We appreciate your patience as we resolve this.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 17,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": "150"\n  },\n  "response": "We take this matter with the highest urgency and sincerity. Data loss during critical business processes is a severe issue that demands immediate investigation and action.\\n\\nTo begin our emergency response, we need the following information:\\n\\n1. Which product or module were you using when the crash occurred?\\n2. What is the account or organization name associated with this incident?\\n3. Approximately what time did the crash happen?\\n4. Do you have any error messages, logs, or system notifications from the time of the incident?\\n5. Have you been able to access your account since the crash, or is it completely inaccessible?\\n\\nOur team is standing by to:\\n- Investigate server logs and system status at the time of your report\\n- Assess whether data recovery is possible\\n- Provide you with a detailed incident timeline and root cause analysis\\n\\nPlease respond with the details above as soon as possible, and provide a direct contact number if you need real-time assistance. We are committed to resolving this critical issue.",\n  "confidence": "medium"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 18,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reaching out. We\'d like to help you resolve this issue as quickly as possible. To better assist you, could you please provide more details:\\n\\n1. Which product or feature are you experiencing an issue with?\\n2. What specific behavior are you observing? (e.g., error message, unexpected result, feature not working)\\n3. Are you seeing any error messages or codes?\\n4. When did this issue start occurring?\\n\\nOnce we have these details, we\'ll be able to investigate and get this resolved for you.",\n  "confidence": "low"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 19,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": "UserVault",\n    "version": "9.1.0",\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reporting this issue immediately. We treat potential data exposure as a critical security matter and are escalating this to our security and engineering teams right away.\\n\\nBased on your report, you\'ve identified a possible privacy breach in UserVault v9.1.0 where other users\' personal information (name, email, phone) may be visible when rapidly switching between tabs on the account settings page. We understand you\'ve reproduced this consistently and that the scope may affect all platform users.\\n\\nWe are taking the following immediate steps:\\n1. Notifying our security team to investigate the root cause\\n2. Reviewing recent code changes to the Settings > Profile section\\n3. Assessing whether any unauthorized access has occurred\\n\\nIn the meantime, we recommend avoiding rapid navigation between account settings tabs as a precaution.\\n\\nTo help us investigate thoroughly, could you confirm:\\n- Approximately how many times were you able to reproduce this issue, and did you access any PII beyond what you initially observed?\\n- Are you able to capture a screenshot or video demonstration of the issue for our security team?\\n\\nWe will prioritize this investigation and follow up with you within 2 hours with an initial assessment. Thank you for your diligence in reporting this responsibly.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 20,
#    'category': 'non_native',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "Ñoño Analytics",\n    "version": "5.4.2",\n    "error_codes": ["VIZ-RENDER-408"],\n    "affected_users": "15"\n  },\n  "response": "Hello José,\\n\\nThank you for reporting this issue. We understand that chart widgets on the Ñoño Analytics dashboard are failing to render since the update to version 5.4.2, with error code VIZ-RENDER-408 appearing after approximately 30 seconds. We recognize this is impacting your analytics team of 15 users who depend on this dashboard for daily reporting.\\n\\nWe are treating this as a high-priority production regression. Our engineering team will investigate the VIZ-RENDER-408 error and the chart rendering failure immediately, focusing on what changed in version 5.4.2 that may have affected visualization rendering.\\n\\nIn the meantime, you\'ve already taken the right troubleshooting steps (clearing cache, testing multiple browsers). We will update you within 2 hours with either a fix or a temporary workaround. Please reply if you notice any additional patterns (e.g., specific chart types failing, or failures only under certain data volumes) as that information will help us resolve this faster.\\n\\nWe appreciate your patience and detailed report.\\n\\nBest regards,\\nSupport Team",\n  "confidence": "high"\n}\n```'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': False, 'reason': 'Priority=P2, expected=P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 21,
#    'category': 'vague',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "report builder",\n    "version": null,\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reporting this issue with the report builder. I understand that your team is experiencing slow report generation and occasional timeouts, and that this may be affecting other departments as well.\\n\\nTo help us investigate and resolve this more quickly, could you please provide a few additional details:\\n\\n1. How frequently are the timeouts occurring? (e.g., every few reports, once per day, etc.)\\n2. Do you have a specific error message or code that appears when a timeout occurs?\\n3. Are there any patterns you\'ve noticed—for example, does it happen with certain report types, sizes, or at specific times of day?\\n4. What is the product version you\'re currently running?\\n\\nWhile we work on diagnosing the root cause, the retry workaround you\'ve identified should continue to function. However, I recognize that this is impacting your team\'s productivity, and we\'re treating this as a priority issue. Please share any additional details you can gather, and we\'ll begin investigating immediately.",\n  "confidence": "high"\n}\n```'}],
#  'categories': {'clean': {'label': 'Clean inputs', 'passed': 3, 'total': 4},
#   'multi_issue': {'label': 'Multi-issue', 'passed': 2, 'total': 2},
#   'vague': {'label': 'Vague/unclear', 'passed': 2, 'total': 3},
#   'non_native': {'label': 'Non-native English', 'passed': 3, 'total': 3},
#   'feature_request': {'label': 'Feature requests', 'passed': 2, 'total': 2},
#   'complex': {'label': 'Complex/long/edge', 'passed': 7, 'total': 7}},
#  'total_passed': 19,
#  'total_cases': 21}

# %% [markdown]
# ## Score Benchmarks
#
# | Stage | Expected Score | What It Means |
# |-------|---------------|---------------|
# | Baseline (broken prompt) | ~4/21 (19%) | The starting point — lots of room to improve |
# | Good single-prompt fix | 9–12/21 (43–57%) | You've addressed the major issues |
# | Strong chain solution | 16–19/21 (76–90%) | Excellent — you've mastered the techniques |
# | Reference solution | 21/21 (100%) | The gold standard |
#
# Don't worry if your baseline is low — that's by design! The goal is to iterate and improve.

# %%
# ============================================================
# CHAIN MODE -- 2-step chain: classify+extract, then draft
# ============================================================

step1_prompt = """
You are a support ticket classifier and entity extractor.

Analyze the support ticket and return ONLY classification and entity data.
Do NOT draft any response to the customer.

## PRIORITY (base on CONTENT only, never tone)

Assign exactly one priority:
- P1: System down OR data loss OR security/privacy breach OR payroll/financial process blocked
- P2: Major feature broken, significant user impact, production regression
- P3: Minor bug, intermittent issue, single user affected, cosmetic defect. Also P3 when intermittent with a workaround available, even if multiple users affected.
- P4: Feature request, suggestion, or missing capability — REGARDLESS of urgency wording

CRITICAL PRIORITY RULES:
- Tone, caps lock, anger, or threatening language does NOT affect priority
- A missing feature that has never existed is always P4
- If multiple issues are present, use the HIGHEST applicable priority
- If too vague to determine severity, default to P3

## ENTITY EXTRACTION (only what is explicitly stated)

- product: proper name of a product or named module — null if not stated. Functional descriptions ("our CRM tool", "the platform") are NOT product names — set to null.
- version: version number — null if not stated
- error_codes: error codes, HTTP status codes, or quoted error messages that appear verbatim — [] if none
- affected_users: specific numeric count as a string — null if no specific number given. Vague words ("several", "many", "some") are NOT numbers.

## OUTPUT FORMAT

Return ONLY valid JSON. No explanation, no markdown fences.

{
  "priority": "P1|P2|P3|P4",
  "entities": {
    "product": "string or null",
    "version": "string or null",
    "error_codes": ["array of strings, empty if none"],
    "affected_users": "numeric string or null"
  },
  "confidence": "high|medium|low",
  "ticket_type": "bug|feature_request|vague|multi_issue"
}
"""

step2_prompt = """
You are a customer support response writer.

You will receive:
1. The original support ticket
2. A structured classification from our triage system (priority, entities, confidence, ticket_type)

Your ONLY job is to draft a professional response to the customer.
Do NOT re-classify or re-extract. Trust the classification provided.

## RESPONSE RULES BY PRIORITY

- P1: Urgent, empathetic tone. Acknowledge severity immediately. State that engineering is engaged.
- P2: Professional, prompt tone. Acknowledge the impact. Commit to an investigation timeline.
- P3: Calm, helpful tone. Acknowledge the issue. Ask clarifying questions if confidence=low or ticket_type=vague.
- P4 (feature_request): See detailed rules below.

## P4 FEATURE REQUEST RESPONSE RULES (CRITICAL)

When ticket_type=feature_request, this is NOT a bug. It is a capability that does not exist yet.

- Acknowledge this as a FEATURE REQUEST, not a bug
- Use language like: "We've logged this as a feature request", "Our product team will review this", "We've noted your interest in this capability"
- NEVER use words like: "fix", "resolve", "investigate", "escalate", "work on this", "next steps", "follow up", "get back to you", "shortly" — those imply a bug is being actioned
- Do NOT ask clarifying questions — you have enough to log it
- Do NOT promise a timeline or delivery
- END the response cleanly after logging the request and setting expectations. The response is complete when the request is acknowledged — do not leave it open-ended
- Tone should be warm and appreciative regardless of how angry or urgent the customer's language was

Example of a correct P4 response (angry SSO ticket):
"Thank you for sharing your requirements around SAML SSO integration. We've logged this as a feature request with our product team. We understand this is important for your security compliance needs. While we're unable to commit to a delivery timeline for new capabilities, your account manager can keep you informed of relevant roadmap updates."

## ADDITIONAL RULES

- Acknowledge ALL issues mentioned in the ticket — never drop one
- For vague tickets (confidence=low): ask clarifying questions, do not make assumptions
- For non-English or broken English: respond in clear English, do not comment on language quality
- Keep the response concise and actionable

## OUTPUT FORMAT

Return ONLY valid JSON. No explanation, no markdown fences.

{
  "priority": "<copy priority string from classification, e.g. P1>",
  "entities": {
    "product": "<copy from classification>",
    "version": "<copy from classification>",
    "error_codes": [],
    "affected_users": "<copy from classification>"
  },
  "confidence": "<copy confidence string from classification>",
  "response": "professional response to the customer"
}
"""

# Run the chain
results_chain = run_eval_suite([step1_prompt, step2_prompt], label="v4 - chain + closed P4")

# %%
results_3 = run_eval_suite(system_prompt_3, label="Enhanced Prompt_v3")
results_3
# Out:
# Mode: single prompt
# Model: claude-haiku-4-5
#
# Running 21 eval cases...
#   Case  1/21... PASS
#   Case  2/21... PASS
#   Case  3/21... PASS
#   Case  4/21... PASS
#   Case  5/21... PASS
#   Case  6/21... PASS
#   Case  7/21... PASS
#   Case  8/21... PASS
#   Case  9/21... PASS
#   Case 10/21... PASS
#   Case 11/21... FAIL [response_coherent: Judge: FAIL]
#   Case 12/21... PASS
#   Case 13/21... PASS
#   Case 14/21... PASS
#   Case 15/21... PASS
#   Case 16/21... PASS
#   Case 17/21... PASS
#   Case 18/21... PASS
#   Case 19/21... PASS
#   Case 20/21... PASS
#   Case 21/21... PASS
#
# Completed in 80.0s
#     <div style="background:#f8fafc;border:2px solid #22c55e;border-radius:12px;padding:24px;margin:16px 0;font-family:system-ui,-apple-system,sans-serif;">
#       <div style="text-align:center;">
#         <div style="font-size:14px;color:#6b7280;text-transform:uppercase;letter-spacing:1px;">Enhanced Prompt_v3</div>
#         <div style="font-size:64px;font-weight:bold;color:#22c55e;">20/21</div>
#         <div style="font-size:24px;color:#22c55e;">(95%)</div>
#         <div style="font-size:16px;color:#6b7280;margin-top:4px;">Baseline: 7/21 (33%) &rarr; Current: 20/21 (95%) <span style="color:#22c55e;font-weight:bold;">[+13]</span></div>
#       </div>
#     </div>
# {'results': [{'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 1,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": null,\n    "version": "4.1.2",\n    "error_codes": ["503", "SVC-503-AUTH"],\n    "affected_users": "500"\n  },\n  "response": "Thank you for reporting this issue. We understand that all 500 users in your organization are currently unable to log into your CRM platform due to a 503 Service Unavailable error (SVC-503-AUTH), which began at 2pm EST today. This is a critical production issue and your sales team being completely blocked is our highest priority.\\n\\nWe are immediately investigating the authentication service and backend systems supporting version 4.1.2. Our engineering team has been notified and is actively working to restore service.\\n\\nWe will provide you with an update within 15 minutes with either a resolution or detailed status. In the meantime, please confirm:\\n1. Are you still experiencing the 503 error, or has the issue changed?\\n2. Do you have any on-premises or backup systems your sales team can access while we work on this?\\n\\nWe appreciate your patience and will prioritize getting your team back online immediately.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 2,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": null,\n    "version": "2.8.0",\n    "error_codes": [],\n    "affected_users": "45"\n  },\n  "response": "Thank you for reporting this issue. We understand that incorrect search results in your inventory management module are impacting your warehouse team\'s daily picking operations, and we take this seriously.\\n\\nWe\'ve noted that this behavior began immediately after the update to version 2.8.0. To investigate further, we need a few clarifying details:\\n\\n1. Can you provide a specific example of a SKU search that returns incorrect results? (e.g., searching for \\"SKU-12345\\" returns what items instead?)\\n2. Are ALL searches returning wrong results, or only certain types of searches (e.g., partial matches, numeric SKUs, etc.)?\\n3. Have you tried clearing your browser cache or logging out and back in?\\n4. Can you confirm whether the search was working correctly in the previous version?\\n\\nIn the meantime, our team is prioritizing this for investigation. Please reply with these details at your earliest convenience so we can move forward with a resolution.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 3,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": null,\n    "version": "5.0.1",\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reporting this issue. We\'ve noted that the tooltip text for the \'Data Retention Policy\' field on the admin settings page is being truncated in version 5.0.1, displaying only \'Data will be retained for...\' when admins hover over it.\\n\\nSince this is a cosmetic defect affecting only the tooltip display on a single field and is not blocking any workflows, we\'ve prioritized this for a future patch release. In the meantime, admins can access the full policy information through the documentation or by checking the field description in the settings help section.\\n\\nWe appreciate you catching this during your training session, and we\'ll work to resolve it in an upcoming update.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P4'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 4,
#    'category': 'clean',
#    'raw_output': '```json\n{\n  "priority": "P4",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": "8"\n  },\n  "response": "Thank you for the feature request. We understand that bulk PDF export would streamline your analytics team\'s workflow and reduce the time spent on repetitive exports. We\'ve documented your request for the product team to review, including the suggested UI elements (Select All checkbox and Export Selected to PDF button) and that this would benefit 8 team members.\\n\\nFeature requests are evaluated based on customer demand, implementation complexity, and alignment with our product roadmap. We\'ll keep you updated if this capability moves forward for future consideration.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 5,
#    'category': 'multi_issue',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": ["500"],\n    "affected_users": "200"\n  },\n  "response": "Thank you for reporting this issue. We understand the urgency given your Friday board deadline.\\n\\nWe have escalated this to our engineering team immediately due to the severity of both reported issues:\\n\\n1. **Billing dashboard inaccuracy** (since Tuesday): This is blocking your payroll process and requires immediate investigation and correction.\\n2. **CSV export feature returning 500 error**: Affecting 200 users across your team.\\n\\nOur team is now investigating root causes for both issues. We will prioritize the billing data accuracy first given the payroll impact, and simultaneously work on restoring the export functionality.\\n\\nWe will provide you with an initial status update within 2 hours and keep you informed of progress. If you have any additional details about the exact time the billing numbers diverged or steps to reproduce the export error, please share those now as they will help us resolve this faster.\\n\\nWe\'re committed to having both issues resolved well before your Friday reporting deadline.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 6,
#    'category': 'multi_issue',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": null,\n    "version": "3.5",\n    "error_codes": [],\n    "affected_users": "12"\n  },\n  "response": "Thank you for reporting both items. I\'ve prioritized your case based on the dashboard data staleness issue affecting your ops team.\\n\\n**Issue 1 – Stale Data in Real-Time Dashboard (3 days)**\\nThis is a significant operational impact. I\'m escalating this to our engineering team immediately. To help us diagnose:\\n- Does the dashboard show any error messages, or does it simply display unchanged data?\\n- Have you tried refreshing the page or clearing your browser cache?\\n- Are all metrics stale, or only specific data feeds?\\n- Can you share a screenshot or the exact time range where you first noticed the staleness?\\n\\n**Issue 2 – Dark Mode Feature Request**\\nThank you for the suggestion. Dark mode is a popular request, and I\'ve logged this as a feature request for our product team to evaluate. We\'ll take it into consideration for future releases.\\n\\nPlease reply with answers to the diagnostic questions above so we can resolve the stale data issue as quickly as possible.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 7,
#    'category': 'vague',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reaching out. We understand you\'re experiencing slowness and errors starting this morning. To help us investigate quickly, could you please provide a few clarifications:\\n\\n1. Which product or module are you using when you encounter these issues?\\n2. What specific error messages or codes (if any) are you seeing?\\n3. Is this affecting only your account, or are others on your team experiencing the same problems?\\n4. Can you share an example of one of the errors or describe what you were trying to do when it occurred?\\n\\nOnce we have these details, we\'ll be able to diagnose the issue and get back to you promptly.",\n  "confidence": "low"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 8,
#    'category': 'vague',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reaching out, and I appreciate your loyalty as a long-time customer. I\'m sorry to hear that you\'ve noticed a decline in quality recently—that\'s not the experience we want you to have.\\n\\nTo help us investigate and address your concerns, I\'d like to gather some specific details:\\n\\n1. Which product or feature(s) are you experiencing issues with?\\n2. Can you describe specific problems or errors you\'ve encountered? (For example: unexpected behavior, performance degradation, missing functionality, error messages, etc.)\\n3. When did you first notice these issues?\\n4. Are there any error codes or messages you\'re seeing?\\n5. How many people on your team are affected?\\n\\nOnce I understand the specifics, I\'ll be able to escalate this appropriately and work toward a resolution. We value your business and want to restore your confidence in our platform.",\n  "confidence": "low"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 9,
#    'category': 'non_native',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": null,\n    "version": "3.2",\n    "error_codes": ["timeout exceeded"],\n    "affected_users": "50"\n  },\n  "response": "Thank you for reporting this issue. We understand this is affecting your production system and your 50 customers. We\'re treating this with high priority.\\n\\nWe\'ve noted the following problems following your update to version 3.2:\\n- Webhooks not firing correctly\\n- Data missing from the dashboard\\n- \\"timeout exceeded\\" errors occurring intermittently\\n\\nTo help us investigate quickly, we need a few clarifications:\\n1. What is the name of the API integration or product/module you\'re using?\\n2. Are the \\"timeout exceeded\\" errors appearing in logs, API responses, or elsewhere?\\n3. When did this issue first occur relative to the version 3.2 update?\\n4. Can you provide a specific example of missing data (e.g., which webhook event, which dashboard metric)?\\n\\nPlease reply with these details and, if possible, relevant error logs or screenshots. We\'ll prioritize getting this resolved for your production environment.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 10,
#    'category': 'non_native',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": null,\n    "version": "2.1",\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reaching out. I understand you\'re experiencing an intermittent issue where a report button sometimes does not respond in your system.\\n\\nTo help us investigate this more effectively, I\'d like to gather a few clarifying details:\\n\\n1. Which product or module are you using when this occurs? (For example, the name of the application or the specific tool within your system)\\n2. Approximately how many users in your team of 6 are consistently affected by this issue?\\n3. When the button does not work, do you see any error message on the screen, or does nothing happen at all?\\n4. Which browser and browser version are you using? (For example, Chrome, Firefox, Safari, and the version number)\\n5. Does refreshing the page or retrying the action resolve the issue?\\n\\nOnce you provide these details, we\'ll be able to diagnose the problem more quickly and determine whether this is a browser compatibility issue or something else. Thank you for your patience.",\n  "confidence": "low"\n}\n```'},
#   {'pass': False,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P4'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': False, 'reason': 'Judge: FAIL'}},
#    'case_id': 11,
#    'category': 'feature_request',
#    'raw_output': '```json\n{\n  "priority": "P4",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": "2000"\n  },\n  "response": "Thank you for bringing this to our attention. We understand that SAML SSO integration is important for your organization\'s security compliance requirements.\\n\\nWe\'ve noted your request for SSO support as a feature request. To help us evaluate this properly, could you please clarify:\\n\\n1. Which specific product or module you are referring to?\\n2. Are there particular SSO protocols or providers (beyond SAML) that are critical for your deployment?\\n3. What is your expected timeline for this capability?\\n\\nOnce we have these details, we can route this to our product team for consideration. We appreciate your business and take compliance requirements seriously. We\'ll follow up with you shortly regarding next steps.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P4'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 12,
#    'category': 'feature_request',
#    'raw_output': '```json\n{\n  "priority": "P4",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for the feedback! We appreciate you taking the time to share this suggestion. A calendar view for task management is a great feature request, and we understand how valuable that visualization could be for your project managers. We\'ll pass this along to our product team for consideration in future releases. If you have any other questions or suggestions in the meantime, please don\'t hesitate to reach out.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 13,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": null,\n    "version": "6.0",\n    "error_codes": [\n      "UPLOAD-TIMEOUT-413",\n      "429"\n    ],\n    "affected_users": "85"\n  },\n  "response": "Dear Sarah,\\n\\nThank you for the detailed report and for documenting these issues so thoroughly. We take the performance degradation you\'re experiencing post-migration very seriously, and I understand the impact this is having on your engineering team.\\n\\nI\'m escalating this immediately to our infrastructure team as a priority case. We\'ve noted all five issues you\'ve identified:\\n\\n1. Page load time increase (1.2s → 8–10s across all modules)\\n2. Real-time notification delays (30–45s vs. near-instant)\\n3. File upload timeouts >5MB (error UPLOAD-TIMEOUT-413)\\n4. Overly aggressive API rate limiting (429 errors at 10 req/min)\\n5. Reporting module query performance degradation (3–5x slower)\\n\\nOur team will investigate whether these stem from the migration configuration, cloud resource allocation, or other infrastructure factors. Given your Enterprise plan SLA requirements and the breadth of impact across 85 users, we\'ll prioritize this accordingly.\\n\\nI\'ll follow up within 24 hours with an initial assessment and proposed meeting times for this week. In the interim, if you have access to any migration logs or can share the specific timeframe when performance began degrading, that would help accelerate our investigation.\\n\\nThank you for your patience.\\n\\nBest regards,\\nSupport Team",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 14,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": null,\n    "version": "2.4.1",\n    "error_codes": ["HTTP 500", "SYNC_FAILED", "NullPointerException"],\n    "affected_users": "30"\n  },\n  "response": "Thank you for reporting this issue and providing detailed error information. We\'ve identified that the /api/v2/users/sync endpoint is returning HTTP 500 errors when processing user names containing special characters (such as apostrophes and accented letters). The underlying cause appears to be a NullPointerException in UserSyncService.java at line 142.\\n\\nWe\'re treating this as a high-priority production issue and will investigate immediately. This impacts your HR integration and affects approximately 30 users with special characters in their names.\\n\\nIn the meantime, if possible, you may consider:\\n- Temporarily working around the issue by testing with a subset of non-special-character names to confirm the root cause\\n- Checking if there are any recent changes to user data that correlate with when this started occurring\\n\\nWe\'ll keep you updated on our progress and aim to provide a fix or workaround as soon as possible. Please reference trace ID abc-123-def-456 in any follow-up communication.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 15,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "Analytics Pro",\n    "version": "4.2",\n    "error_codes": ["analytics_basic"],\n    "affected_users": "8"\n  },\n  "response": "Thank you for reporting this issue. We understand you purchased Analytics Pro but are experiencing three related problems: advanced cohort analysis is unavailable, the custom funnel builder is requesting an upgrade despite your Pro subscription, and the /account endpoint is returning your plan as \\"analytics_basic\\" instead of Pro. This strongly suggests a provisioning or account synchronization error on our end.\\n\\nWe\'re treating this as a priority issue given that your data team of 8 is blocked from promised Pro functionality. We\'ll immediately investigate:\\n\\n1. Your account provisioning status in our billing system\\n2. Why the API is returning the incorrect plan tier\\n3. Feature access synchronization across the module\\n\\nA support engineer will contact you within the next 2 hours with an update and next steps. In the meantime, please preserve any screenshots or API responses showing the \\"analytics_basic\\" return value—these will help us accelerate the diagnosis.\\n\\nWe apologize for this impact and will work to restore your Pro access quickly.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 16,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": null,\n    "version": "3.1",\n    "error_codes": [],\n    "affected_users": "25"\n  },\n  "response": "Thank you for the follow-up on Case #4821. I understand that while the hourly syncs have resumed, you\'re now experiencing duplicate records being created on each sync cycle — a regression from the original missing data issue.\\n\\nI\'m escalating this immediately to the engineering team to review whether the deduplication logic was included in last week\'s patch. This is clearly impacting your 25 users and needs urgent attention.\\n\\nI\'ll investigate the patch details and follow up with you within 2 hours with either a fix or a workaround. In the meantime, if you\'re able to share:\\n- Approximately how many duplicate records are being created per sync cycle?\\n- Are duplicates affecting all 25 users or a subset?\\n\\nThis will help us prioritize and validate the fix once deployed.\\n\\nThank you for your patience, and I apologize for this disruption.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 17,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": "150"\n  },\n  "response": "We understand this is a critical situation and we are treating it with the highest urgency. We have immediately escalated your report of system crash and data loss to our senior engineering and operations teams.\\n\\nTo begin our investigation and recovery efforts, we need the following information as quickly as possible:\\n\\n1. Exact timestamp of when the crash occurred\\n2. Which specific product or module was affected when the system crashed\\n3. Any error messages or codes displayed before or during the crash\\n4. Which reports were affected and in what format they were stored\\n5. Your account/organization name and primary contact information\\n\\nOur Data Recovery and Infrastructure teams are standing by. A senior support engineer will contact you directly within the next 30 minutes to coordinate immediate troubleshooting and assess recovery options.\\n\\nWe take data integrity and system reliability seriously. Please reply with the information above as soon as possible so we can work toward resolution.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 18,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reaching out. I\'d like to help you resolve this issue as quickly as possible, but I need a bit more information to assist you effectively.\\n\\nCould you please provide the following details:\\n\\n1. **What is broken?** (e.g., a specific feature, page, or functionality)\\n2. **What product or module** are you using?\\n3. **What were you trying to do** when the issue occurred?\\n4. **What error message or behavior** are you seeing?\\n5. **When did this start?** (e.g., today, this week)\\n\\nOnce I have these details, I\'ll be able to investigate and get this resolved for you.",\n  "confidence": "low"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P1'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True, 'reason': 'Judge: PASS'}},
#    'case_id': 19,
#    'category': 'complex',
#    'raw_output': '```json\n{\n  "priority": "P1",\n  "entities": {\n    "product": "UserVault",\n    "version": "9.1.0",\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reporting this critical security issue. A data exposure vulnerability of this nature requires immediate investigation and remediation.\\n\\nWe have escalated your report to our security team and engineering leadership. Based on your description, we are treating this as a potential security breach affecting all platform users until proven otherwise.\\n\\nTo help us investigate and resolve this urgently:\\n1. Can you confirm the exact steps to reproduce (e.g., which browser, how many clicks, timing)?\\n2. Did you capture any screenshots or video of the exposed data?\\n3. Can you provide the approximate time(s) when you reproduced this?\\n\\nIn the meantime, we strongly recommend you change your password immediately as a precaution.\\n\\nWe will prioritize a fix and provide you with an update within 2 hours. If you discover any additional details or are able to reproduce this again, please reply immediately.",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P2'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 20,
#    'category': 'non_native',
#    'raw_output': '```json\n{\n  "priority": "P2",\n  "entities": {\n    "product": "Ñoño Analytics",\n    "version": "5.4.2",\n    "error_codes": ["VIZ-RENDER-408"],\n    "affected_users": "15"\n  },\n  "response": "Dear José,\\n\\nThank you for reporting this issue. We understand how critical dashboard visualization is for your team\'s daily reporting workflows.\\n\\nWe have received your report about the Ñoño Analytics dashboard charts failing to render after the update to version 5.4.2, with error code VIZ-RENDER-408 appearing after 30 seconds. We note that data tables load correctly, which helps narrow the scope to the visualization layer.\\n\\nWe are investigating this regression immediately. In the meantime, since your team relies on this for daily reporting, please confirm:\\n1. Are you able to export the underlying data from the tables as a temporary workaround for today\'s reporting needs?\\n2. Have you noticed if any specific chart types fail, or is this affecting all visualization widgets?\\n3. Are there any custom filters or dashboard configurations that were in use before the update?\\n\\nWe will prioritize a fix and follow up with you within 2 hours with either a resolution or a detailed status update.\\n\\nBest regards,\\nSupport Team",\n  "confidence": "high"\n}\n```'},
#   {'pass': True,
#    'criteria': {'json_valid': {'pass': True,
#      'reason': 'Valid JSON with all required fields'},
#     'priority_correct': {'pass': True, 'reason': 'Priority correct: P3'},
#     'entities_accurate': {'pass': True,
#      'reason': 'All entities derivable from input'},
#     'response_coherent': {'pass': True,
#      'reason': 'Auto-pass (non-audited case)'}},
#    'case_id': 21,
#    'category': 'vague',
#    'raw_output': '```json\n{\n  "priority": "P3",\n  "entities": {\n    "product": null,\n    "version": null,\n    "error_codes": [],\n    "affected_users": null\n  },\n  "response": "Thank you for reporting this issue with the report builder. We appreciate you taking the time to document the performance problems you and your team have been experiencing.\\n\\nWe understand that reports are occasionally timing out and taking longer than expected to generate, though you\'ve noted that retrying typically resolves the issue. We\'d like to investigate this further to improve reliability.\\n\\nTo help us diagnose the root cause, could you please provide:\\n\\n1. Specific examples of report names or types that are timing out most frequently\\n2. Approximate timeframes of when these delays have been occurring\\n3. The typical size or complexity of the reports that are affected (number of rows, data sources, etc.)\\n4. Any error messages or codes displayed when timeouts occur\\n5. Whether this is a recent change in behavior or has been ongoing\\n\\nWhile we work on a resolution, the retry workaround should help you continue your work. Once we have more details, we\'ll be able to prioritize a fix accordingly.\\n\\nPlease reply with any additional information you can share.",\n  "confidence": "medium"\n}\n```'}],
#  'categories': {'clean': {'label': 'Clean inputs', 'passed': 4, 'total': 4},
#   'multi_issue': {'label': 'Multi-issue', 'passed': 2, 'total': 2},
#   'vague': {'label': 'Vague/unclear', 'passed': 3, 'total': 3},
#   'non_native': {'label': 'Non-native English', 'passed': 3, 'total': 3},
#   'feature_request': {'label': 'Feature requests', 'passed': 1, 'total': 2},
#   'complex': {'label': 'Complex/long/edge', 'passed': 7, 'total': 7}},
#  'total_passed': 20,
#  'total_cases': 21}

# %% [markdown]
# ## Diagnosis Guidance
#
# Before you start fixing, spend 10–15 minutes *understanding* what's wrong. Treat this like a real engagement — diagnose before you prescribe.
#
# ### Where to focus
#
# Look at the **category breakdown** from your baseline eval:
# - Which categories score 0? Those are your highest-leverage targets.
# - Which categories already pass? Protect those — fixes for hard cases often break easy ones.
#
# ### Patterns to look for in the failing examples
#
# 1. **Task interference** — The prompt asks the model to classify, extract, *and* draft a response simultaneously. When the response-drafting task activates empathetic language, it can inflate the priority classification. When extraction finds nothing, the model invents entities to fill the fields.
#
# 2. **Hallucinated entities** — The prompt says "Always include all JSON fields even if empty." The model interprets "include" as "fill in" rather than "leave as null." Vague tickets trigger fabricated product names and error codes.
#
# 3. **Emotional tone biasing priority** — The prompt defines P1 as "system down, all users affected" but doesn't say *ignore the tone and focus on the content*. Angry or urgent language inflates priority even when the actual issue is a feature request.
#
# 4. **Feature requests misclassified** — Without explicit examples showing that urgent-sounding feature requests are still P4, the model defaults to matching urgency words to high priority levels.
#
# ### Try meta-prompting
#
# Paste the broken prompt into a fresh Claude conversation along with 2–3 failing examples. Ask:
#
# > "What structural issues in this prompt could cause these outputs? Be specific about which instructions are ambiguous, conflicting, or missing."
#
# This is one of the most powerful diagnostic tools in your toolkit — use Claude to analyze its own prompt.

# %% [markdown]
# ## Your Toolkit
#
# Four techniques, each suited to different failure modes. Pick based on your diagnosis — the rubric rewards *rationale*, not technique count.
#
# ### 1. Meta-prompting
# **What it is:** Use Claude to analyze and improve the prompt itself.
#
# **When to use it:** When you can't figure out *why* the prompt fails, or when you want to systematically surface ambiguities.
#
# **How:** Paste the broken prompt + failing examples into Claude and ask it to identify structural issues, suggest rewrites, or generate improved instructions.
#
# ---
#
# ### 2. Prompt chaining
# **What it is:** Decompose a monolithic prompt into a multi-step pipeline where each step has a focused responsibility.
#
# **When to use it:** When the prompt does too many things at once and the tasks interfere with each other (classification accuracy drops when the model is simultaneously drafting responses).
#
# **How:** Split into steps like: Classify priority -> Extract entities -> Draft response. Each step gets its own system prompt. The eval harness supports chain mode — pass a list of prompts.
#
# **Tradeoff:** Each chain step is a separate API call. The customer's latency budget is 5 seconds, so 3 sequential calls need to each complete in ~1.5s.
#
# ---
#
# ### 3. A/B testing
# **What it is:** Run competing prompt variants against the same eval set and compare quantitatively.
#
# **When to use it:** When you're unsure which framing, instruction set, or architecture works better.
#
# **How:** Use `compare_prompts(prompt_a, prompt_b)` to run both variants and see a side-by-side category breakdown.
#
# ---
#
# ### 4. Automatic prompt optimization
# **What it is:** Systematic iteration loops — generate variants, eval each, select the best.
#
# **When to use it:** When you've plateaued and need to systematically explore the solution space.
#
# **How:** Write a loop that generates prompt variants (using meta-prompting), evals each, and keeps the best performer. Manual version: try 3 variants of the trickiest instruction, eval all 3, keep the winner.

# %%
# ============================================================
# CHAIN MODE -- 2-step chain: classify+extract, then draft
# ============================================================

step1_prompt = """
You are a support ticket classifier and entity extractor.

Analyze the support ticket and return ONLY classification and entity data.
Do NOT draft any response to the customer.

## PRIORITY (base on CONTENT only, never tone)

Assign exactly one priority:
- P1: System down OR data loss OR security/privacy breach OR payroll/financial process blocked
- P2: Major feature broken, significant user impact, production regression
- P3: Minor bug, intermittent issue, single user affected, cosmetic defect. Also P3 when intermittent with a workaround available, even if multiple users affected.
- P4: Feature request, suggestion, or missing capability — REGARDLESS of urgency wording

CRITICAL PRIORITY RULES:
- Tone, caps lock, anger, or threatening language does NOT affect priority
- A missing feature that has never existed is always P4
- If multiple issues are present, use the HIGHEST applicable priority
- If too vague to determine severity, default to P3

## ENTITY EXTRACTION (only what is explicitly stated)

- product: proper name of a product or named module — null if not stated. Functional descriptions ("our CRM tool", "the platform") are NOT product names — set to null.
- version: version number — null if not stated
- error_codes: error codes, HTTP status codes, or quoted error messages that appear verbatim — [] if none
- affected_users: specific numeric count as a string — null if no specific number given. Vague words ("several", "many", "some") are NOT numbers.

## OUTPUT FORMAT

Return ONLY valid JSON. No explanation, no markdown fences.

{
  "priority": "P1|P2|P3|P4",
  "entities": {
    "product": "string or null",
    "version": "string or null",
    "error_codes": ["array of strings, empty if none"],
    "affected_users": "numeric string or null"
  },
  "confidence": "high|medium|low",
  "ticket_type": "bug|feature_request|vague|multi_issue"
}
"""

step2_prompt = """
You are a customer support response writer.

You will receive:
1. The original support ticket
2. A structured classification from our triage system (priority, entities, confidence, ticket_type)

Your ONLY job is to draft a professional response to the customer.
Do NOT re-classify or re-extract. Trust the classification provided.

## RESPONSE RULES

- P1: Urgent, empathetic tone. Acknowledge the severity immediately. State that engineering is engaged.
- P2: Professional, prompt tone. Acknowledge the impact. Commit to investigation timeline.
- P3: Calm, helpful tone. Acknowledge the issue. Ask clarifying questions if confidence=low or ticket_type=vague.
- P4 (feature_request): Warm, appreciative tone. Acknowledge as a FEATURE REQUEST. Do NOT promise to fix it. Do NOT treat it as a bug. Log it for the product team.

ADDITIONAL RULES:
- Acknowledge ALL issues mentioned in the ticket — never drop one
- For vague tickets (confidence=low): ask clarifying questions, do not make assumptions
- For non-English or broken English: respond in clear English, do not comment on language quality
- Keep the response concise and actionable

## OUTPUT FORMAT

Return ONLY valid JSON. No explanation, no markdown fences.

{
  "priority": "<copy from classification>",
  "entities": "<copy from classification>",
  "confidence": "<copy from classification>",
  "response": "professional response to the customer"
}
"""

# %%
# ============================================================
# CHAIN MODE -- 2-step chain: classify+extract, then draft
# ============================================================

step1_prompt = """
You are a support ticket classifier and entity extractor.

Analyze the support ticket and return ONLY classification and entity data.
Do NOT draft any response to the customer.

## PRIORITY (base on CONTENT only, never tone)

Assign exactly one priority:
- P1: System down OR data loss OR security/privacy breach OR payroll/financial process blocked
- P2: Major feature broken, significant user impact, production regression
- P3: Minor bug, intermittent issue, single user affected, cosmetic defect. Also P3 when intermittent with a workaround available, even if multiple users affected.
- P4: Feature request, suggestion, or missing capability — REGARDLESS of urgency wording

CRITICAL PRIORITY RULES:
- Tone, caps lock, anger, or threatening language does NOT affect priority
- A missing feature that has never existed is always P4
- If multiple issues are present, use the HIGHEST applicable priority
- If too vague to determine severity, default to P3

## ENTITY EXTRACTION (only what is explicitly stated)

- product: proper name of a product or named module — null if not stated. Functional descriptions ("our CRM tool", "the platform") are NOT product names — set to null.
- version: version number — null if not stated
- error_codes: error codes, HTTP status codes, or quoted error messages that appear verbatim — [] if none
- affected_users: specific numeric count as a string — null if no specific number given. Vague words ("several", "many", "some") are NOT numbers.

## OUTPUT FORMAT

Return ONLY valid JSON. No explanation, no markdown fences.

{
  "priority": "P1|P2|P3|P4",
  "entities": {
    "product": "string or null",
    "version": "string or null",
    "error_codes": ["array of strings, empty if none"],
    "affected_users": "numeric string or null"
  },
  "confidence": "high|medium|low",
  "ticket_type": "bug|feature_request|vague|multi_issue"
}
"""

step2_prompt = """
You are a customer support response writer.

You will receive:
1. The original support ticket
2. A structured classification from our triage system (priority, entities, confidence, ticket_type)

Your ONLY job is to draft a professional response to the customer.
Do NOT re-classify or re-extract. Trust the classification provided.

## RESPONSE RULES BY PRIORITY

- P1: Urgent, empathetic tone. Acknowledge severity immediately. State that engineering is engaged.
- P2: Professional, prompt tone. Acknowledge the impact. Commit to an investigation timeline.
- P3: Calm, helpful tone. Acknowledge the issue. Ask clarifying questions if confidence=low or ticket_type=vague.
- P4 (feature_request): See detailed rules below.

## P4 FEATURE REQUEST RESPONSE RULES (CRITICAL)

When ticket_type=feature_request:
- Acknowledge this as a FEATURE REQUEST, not a bug
- Use language like: "We've logged this as a feature request", "Our product team will review this", "We've noted your interest in this capability"
- NEVER use words like: "fix", "resolve", "investigate", "escalate", "work on this" — those imply a bug is being worked
- Do NOT promise a timeline or delivery
- Tone should be warm and appreciative regardless of how angry or urgent the customer's language was
- Example of a correct P4 response: "Thank you for sharing this. We've logged SAML SSO support as a feature request with our product team. While we can't commit to a timeline, we appreciate you detailing your requirements. Your account manager can keep you updated on roadmap developments."

## ADDITIONAL RULES

- Acknowledge ALL issues mentioned in the ticket — never drop one
- For vague tickets (confidence=low): ask clarifying questions, do not make assumptions
- For non-English or broken English: respond in clear English, do not comment on language quality
- Keep the response concise and actionable

## OUTPUT FORMAT

Return ONLY valid JSON. No explanation, no markdown fences.

{
  "priority": "<copy priority string from classification, e.g. P1>",
  "entities": {
    "product": "<copy from classification>",
    "version": "<copy from classification>",
    "error_codes": [],
    "affected_users": "<copy from classification>"
  },
  "confidence": "<copy confidence string from classification>",
  "response": "professional response to the customer"
}
"""

# %%
# Run the chain
results_chain = run_eval_suite([step1_prompt, step2_prompt], label="v4 - 2-step chain")
# Out:
# Mode: 2-step chain
# Model: claude-haiku-4-5
#
# Running 21 eval cases...
#   Case  1/21... PASS
#   Case  2/21... PASS
#   Case  3/21... PASS
#   Case  4/21... PASS
#   Case  5/21... PASS
#   Case  6/21... PASS
#   Case  7/21... PASS
#   Case  8/21... PASS
#   Case  9/21... PASS
#   Case 10/21... PASS
#   Case 11/21... FAIL [response_coherent: Judge: FAIL]
#   Case 12/21... PASS
#   Case 13/21... PASS
#   Case 14/21... PASS
#   Case 15/21... PASS
#   Case 16/21... PASS
#   Case 17/21... PASS
#   Case 18/21... PASS
#   Case 19/21... PASS
#   Case 20/21... PASS
#   Case 21/21... PASS
#
# Completed in 94.9s
#     <div style="background:#f8fafc;border:2px solid #22c55e;border-radius:12px;padding:24px;margin:16px 0;font-family:system-ui,-apple-system,sans-serif;">
#       <div style="text-align:center;">
#         <div style="font-size:14px;color:#6b7280;text-transform:uppercase;letter-spacing:1px;">v4 - 2-step chain</div>
#         <div style="font-size:64px;font-weight:bold;color:#22c55e;">20/21</div>
#         <div style="font-size:24px;color:#22c55e;">(95%)</div>
#         <div style="font-size:16px;color:#6b7280;margin-top:4px;">Baseline: 7/21 (33%) &rarr; Current: 20/21 (95%) <span style="color:#22c55e;font-weight:bold;">[+13]</span></div>
#       </div>
#     </div>

# %%
results_chain = run_eval_suite([step1_prompt, step2_prompt], label="v4b - 2-step chain")
# Out:
# Mode: 2-step chain
# Model: claude-haiku-4-5
#
# Running 21 eval cases...
#   Case  1/21... PASS
#   Case  2/21... PASS
#   Case  3/21... PASS
#   Case  4/21... PASS
#   Case  5/21... PASS
#   Case  6/21... PASS
#   Case  7/21... PASS
#   Case  8/21... PASS
#   Case  9/21... PASS
#   Case 10/21... PASS
#   Case 11/21... FAIL [response_coherent: Judge: FAIL]
#   Case 12/21... PASS
#   Case 13/21... PASS
#   Case 14/21... PASS
#   Case 15/21... PASS
#   Case 16/21... PASS
#   Case 17/21... PASS
#   Case 18/21... PASS
#   Case 19/21... PASS
#   Case 20/21... PASS
#   Case 21/21... PASS
#
# Completed in 99.4s
#     <div style="background:#f8fafc;border:2px solid #22c55e;border-radius:12px;padding:24px;margin:16px 0;font-family:system-ui,-apple-system,sans-serif;">
#       <div style="text-align:center;">
#         <div style="font-size:14px;color:#6b7280;text-transform:uppercase;letter-spacing:1px;">v4b - 2-step chain</div>
#         <div style="font-size:64px;font-weight:bold;color:#22c55e;">20/21</div>
#         <div style="font-size:24px;color:#22c55e;">(95%)</div>
#         <div style="font-size:16px;color:#6b7280;margin-top:4px;">Baseline: 7/21 (33%) &rarr; Current: 20/21 (95%) <span style="color:#22c55e;font-weight:bold;">[+13]</span></div>
#       </div>
#     </div>

# %%
# ============================================================
# CHAIN MODE -- Use this if you split into multiple steps
# ============================================================

# Step 1: Classifier
step1_prompt = """
[Your classifier prompt here -- focus on priority classification only]
"""

# Step 2: Entity Extractor
step2_prompt = """
[Your entity extraction prompt here -- extract product, version, error codes, affected users]
"""

# Step 3: Response Drafter
step3_prompt = """
[Your response drafter prompt here -- draft a customer response and assemble final JSON]
"""

# Run the chain (uncomment when ready)
# results = run_eval_suite([step1_prompt, step2_prompt, step3_prompt], label="Chain v1")

# %%
# ============================================================
# A/B COMPARISON -- Compare two prompt variants
# ============================================================

prompt_a = system_prompt  # Your current best

prompt_b = """
[Paste your variant here]
"""

# Run comparison (uncomment when ready)
# result_a, result_b = compare_prompts(prompt_a, prompt_b, label_a="Current Best", label_b="New Variant")

# %%
# ============================================================
# ITERATION LOG -- Track your progress across runs
# ============================================================

# The eval harness automatically logs each run.
# Call this to see your iteration history and score progression:

show_iteration_log()

# %% [markdown]
# ## Reflect on Your Approach
#
# Take 5 minutes to reflect on your work and what you learned:
#
# 1. **Root cause analysis:** What was structurally wrong with the original prompt, and why did it produce each failure mode? Reference specific failing examples from the diagnosis material.
#
# 2. **Technique selection:** Which techniques did you use and why? What specific failure mode does each technique address?
#
# 3. **Iteration insights:** What did you try? What worked, what didn't, and what would you do with more time?
#
# 4. **Prevention advice:** If you were consulting for TechSupport Corp, what would you tell them to avoid these issues in future prompts?
#
# ### Share at Your Table
#
# When you're ready, share your approach with others at your table:
# - What was the trickiest failure mode to fix?
# - Which technique had the biggest impact on your score?
# - What surprised you most about how the prompt was failing?

# %% [markdown]
# ## Wrapping Up
#
# Before we wrap up the session, we'd love to hear from a few people — no need to prepare anything formal. Be ready to share:
#
# - **One thing you tried:** What was your main fix or technique?
# - **One result:** Did it work? What was the impact on your score?
# - **One surprise:** What surprised you most about the prompt engineering process?
#
# This helps us all learn from each other's approaches.
